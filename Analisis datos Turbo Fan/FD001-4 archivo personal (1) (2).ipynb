# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fd_001 =pd.read_csv("/content/drive/MyDrive/Cmapss/CMAPSS/CMaps/train_FD001.txt",sep=" ",header=None)

# %%
fd_001
# Out:
#         0    1       2       3      4       5       6        7        8   \
# 0        1    1 -0.0007 -0.0004  100.0  518.67  641.82  1589.70  1400.60
# 1        1    2  0.0019 -0.0003  100.0  518.67  642.15  1591.82  1403.14
# 2        1    3 -0.0043  0.0003  100.0  518.67  642.35  1587.99  1404.20
# 3        1    4  0.0007  0.0000  100.0  518.67  642.35  1582.79  1401.87
# 4        1    5 -0.0019 -0.0002  100.0  518.67  642.37  1582.85  1406.22
# ...    ...  ...     ...     ...    ...     ...     ...      ...      ...
# 20626  100  196 -0.0004 -0.0003  100.0  518.67  643.49  1597.98  1428.63
# 20627  100  197 -0.0016 -0.0005  100.0  518.67  643.54  1604.50  1433.58
# 20628  100  198  0.0004  0.0000  100.0  518.67  643.42  1602.46  1428.18
# 20629  100  199 -0.0011  0.0003  100.0  518.67  643.23  1605.26  1426.53
# 20630  100  200 -0.0032 -0.0005  100.0  518.67  643.85  1600.38  1432.14
#
#           9   ...       18      19    20   21    22     23     24       25  \
# 0      14.62  ...  8138.62  8.4195  0.03  392  2388  100.0  39.06  23.4190
# 1      14.62  ...  8131.49  8.4318  0.03  392  2388  100.0  39.00  23.4236
# 2      14.62  ...  8133.23  8.4178  0.03  390  2388  100.0  38.95  23.3442
# 3      14.62  ...  8133.83  8.3682  0.03  392  2388  100.0  38.88  23.3739
# 4      14.62  ...  8133.80  8.4294  0.03  393  2388  100.0  38.90  23.4044
# ...      ...  ...      ...     ...   ...  ...   ...    ...    ...      ...
# 20626  14.62  ...  8137.60  8.4956  0.03  397  2388  100.0  38.49  22.9735
# 20627  14.62  ...  8136.50  8.5139  0.03  395  2388  100.0  38.30  23.1594
# 20628  14.62  ...  8141.05  8.5646  0.03  398  2388  100.0  38.44  22.9333
# 20629  14.62  ...  8139.29  8.5389  0.03  395  2388  100.0  38.29  23.0640
# 20630  14.62  ...  8137.33  8.5036  0.03  396  2388  100.0  38.37  23.0522
#
#        26  27
# 0     NaN NaN
# 1     NaN NaN
# 2     NaN NaN
# 3     NaN NaN
# 4     NaN NaN
# ...    ..  ..
# 20626 NaN NaN
# 20627 NaN NaN
# 20628 NaN NaN
# 20629 NaN NaN
# 20630 NaN NaN
#
# [20631 rows x 28 columns]

# %%
fd_001.drop(columns=[26,27],inplace=True)

# %%
columns = ['unit_number','time_in_cycles','setting_1','setting_2','TRA','T2','T24','T30','T50','P2','P15','P30','Nf','Nc','epr','Ps30','phi','NRf','NRc','BPR','farB','htBleed','Nf_dmd','PCNfR_dmd','W31','W32']

# %%
fd_001.columns = columns

# %%
fd_001
# Out:
#        unit_number  time_in_cycles  setting_1  setting_2    TRA      T2  \
# 0                1               1    -0.0007    -0.0004  100.0  518.67
# 1                1               2     0.0019    -0.0003  100.0  518.67
# 2                1               3    -0.0043     0.0003  100.0  518.67
# 3                1               4     0.0007     0.0000  100.0  518.67
# 4                1               5    -0.0019    -0.0002  100.0  518.67
# ...            ...             ...        ...        ...    ...     ...
# 20626          100             196    -0.0004    -0.0003  100.0  518.67
# 20627          100             197    -0.0016    -0.0005  100.0  518.67
# 20628          100             198     0.0004     0.0000  100.0  518.67
# 20629          100             199    -0.0011     0.0003  100.0  518.67
# 20630          100             200    -0.0032    -0.0005  100.0  518.67
#
#           T24      T30      T50     P2  ...     phi      NRf      NRc     BPR  \
# 0      641.82  1589.70  1400.60  14.62  ...  521.66  2388.02  8138.62  8.4195
# 1      642.15  1591.82  1403.14  14.62  ...  522.28  2388.07  8131.49  8.4318
# 2      642.35  1587.99  1404.20  14.62  ...  522.42  2388.03  8133.23  8.4178
# 3      642.35  1582.79  1401.87  14.62  ...  522.86  2388.08  8133.83  8.3682
# 4      642.37  1582.85  1406.22  14.62  ...  522.19  2388.04  8133.80  8.4294
# ...       ...      ...      ...    ...  ...     ...      ...      ...     ...
# 20626  643.49  1597.98  1428.63  14.62  ...  519.49  2388.26  8137.60  8.4956
# 20627  643.54  1604.50  1433.58  14.62  ...  519.68  2388.22  8136.50  8.5139
# 20628  643.42  1602.46  1428.18  14.62  ...  520.01  2388.24  8141.05  8.5646
# 20629  643.23  1605.26  1426.53  14.62  ...  519.67  2388.23  8139.29  8.5389
# 20630  643.85  1600.38  1432.14  14.62  ...  519.30  2388.26  8137.33  8.5036
#
#        farB  htBleed  Nf_dmd  PCNfR_dmd    W31      W32
# 0      0.03      392    2388      100.0  39.06  23.4190
# 1      0.03      392    2388      100.0  39.00  23.4236
# 2      0.03      390    2388      100.0  38.95  23.3442
# 3      0.03      392    2388      100.0  38.88  23.3739
# 4      0.03      393    2388      100.0  38.90  23.4044
# ...     ...      ...     ...        ...    ...      ...
# 20626  0.03      397    2388      100.0  38.49  22.9735
# 20627  0.03      395    2388      100.0  38.30  23.1594
# 20628  0.03      398    2388      100.0  38.44  22.9333
# 20629  0.03      395    2388      100.0  38.29  23.0640
# 20630  0.03      396    2388      100.0  38.37  23.0522
#
# [20631 rows x 26 columns]

# %%
def prepare_train_data(data, factor = 0):
 # Hacer una copia del DataFrame original para evitar cambios en el DataFrame original
 df = data.copy()

 # Agrupar por 'unit_number' y encontrar el máximo 'time_in_cycles' para cada grupo
 # reset_index() se usa para convertir 'unit_number' de un índice a una columna
 fd_RUL = df.groupby('unit_number')['time_in_cycles'].max().reset_index()

 # Cambiar el nombre de la columna 'time_in_cycles' a 'max'
 fd_RUL.rename(columns = {'time_in_cycles':'max'}, inplace = True)

 # Combinar el DataFrame original con fd_RUL basado en 'unit_number'
 # Esto agrega la columna 'max' al DataFrame original
 df = df.merge(fd_RUL, on=['unit_number'], how='left')

 # Calcular la columna 'RUL' como la diferencia entre 'max' y 'time_in_cycles'
 df['RUL'] = df['max'] - df['time_in_cycles']

 # Eliminar la columna 'max' ya que ya no es necesaria
 df.drop(columns=['max'],inplace = True)

 # Devolver solo las filas donde 'time_in_cycles' es mayor que el factor dado
 return df[df['time_in_cycles'] > factor]

# %%
df = prepare_train_data (fd_001)

# %%
df
# Out:
#        unit_number  time_in_cycles  setting_1  setting_2    TRA      T2  \
# 0                1               1    -0.0007    -0.0004  100.0  518.67
# 1                1               2     0.0019    -0.0003  100.0  518.67
# 2                1               3    -0.0043     0.0003  100.0  518.67
# 3                1               4     0.0007     0.0000  100.0  518.67
# 4                1               5    -0.0019    -0.0002  100.0  518.67
# ...            ...             ...        ...        ...    ...     ...
# 20626          100             196    -0.0004    -0.0003  100.0  518.67
# 20627          100             197    -0.0016    -0.0005  100.0  518.67
# 20628          100             198     0.0004     0.0000  100.0  518.67
# 20629          100             199    -0.0011     0.0003  100.0  518.67
# 20630          100             200    -0.0032    -0.0005  100.0  518.67
#
#           T24      T30      T50     P2  ...      NRf      NRc     BPR  farB  \
# 0      641.82  1589.70  1400.60  14.62  ...  2388.02  8138.62  8.4195  0.03
# 1      642.15  1591.82  1403.14  14.62  ...  2388.07  8131.49  8.4318  0.03
# 2      642.35  1587.99  1404.20  14.62  ...  2388.03  8133.23  8.4178  0.03
# 3      642.35  1582.79  1401.87  14.62  ...  2388.08  8133.83  8.3682  0.03
# 4      642.37  1582.85  1406.22  14.62  ...  2388.04  8133.80  8.4294  0.03
# ...       ...      ...      ...    ...  ...      ...      ...     ...   ...
# 20626  643.49  1597.98  1428.63  14.62  ...  2388.26  8137.60  8.4956  0.03
# 20627  643.54  1604.50  1433.58  14.62  ...  2388.22  8136.50  8.5139  0.03
# 20628  643.42  1602.46  1428.18  14.62  ...  2388.24  8141.05  8.5646  0.03
# 20629  643.23  1605.26  1426.53  14.62  ...  2388.23  8139.29  8.5389  0.03
# 20630  643.85  1600.38  1432.14  14.62  ...  2388.26  8137.33  8.5036  0.03
#
#        htBleed  Nf_dmd  PCNfR_dmd    W31      W32  RUL
# 0          392    2388      100.0  39.06  23.4190  191
# 1          392    2388      100.0  39.00  23.4236  190
# 2          390    2388      100.0  38.95  23.3442  189
# 3          392    2388      100.0  38.88  23.3739  188
# 4          393    2388      100.0  38.90  23.4044  187
# ...        ...     ...        ...    ...      ...  ...
# 20626      397    2388      100.0  38.49  22.9735    4
# 20627      395    2388      100.0  38.30  23.1594    3
# 20628      398    2388      100.0  38.44  22.9333    2
# 20629      395    2388      100.0  38.29  23.0640    1
# 20630      396    2388      100.0  38.37  23.0522    0
#
# [20631 rows x 27 columns]

# %% [markdown]
# FD001
# Explicacion del experimento: En esta experiencia, la evaluacion busca analizaz en base al numero de turbinas puestas a pruebas segun CMAPSS, la relacion de cada ciclo de prueba en funcion a RUL( Vida util Restante)
#
# Analisis de Resultados
# Segun grafico adjunto en Codigo, se evidencia que de 100 turbinas sometidas a pruebas de trabajo segun variables medidas CMAPSS, da como resultado, que la turbina N°69, es la que mas dura segun el modelo de la propagación de daños en motores de turbina de gas, y la menos duradera, fue la turbina N°39.

# %%
#Veamos cada campaña
plt.figure(figsize=(20,6))
df.unit_number.value_counts().plot.bar()
plt.xlabel('Id Simulado')
plt.ylabel('Cantidad de puntos')
# Out:
# Text(0, 0.5, 'Cantidad de puntos')

# %%
# Definimos la variable dependiente que queremos analizar. En este caso, 'RUL' (Remaining Useful Life).
dependent_var = ['RUL']

# Creamos un gráfico de dispersión (scatter plot) utilizando PairGrid de seaborn.
# Se filtran los datos para considerar solo las unidades con 'unit_number' menor a 100.
# Los gráficos de dispersión se crearán para cada variable (columnas) en el DataFrame 'df', utilizando 'RUL' como la variable en el eje x.
g = sns.PairGrid(data=df.query('unit_number < 100'), # Filtramos los datos para unidades menores a 100
                 x_vars=dependent_var, # Variable independiente 'RUL'
                 y_vars=df.columns, # Columnas del DataFrame a comparar contra 'RUL'
                 hue="unit_number", # Coloreamos los puntos según el 'unit_number'
                 height=2, # Altura de cada gráfico
                 aspect=5) # Relación de aspecto para los gráficos

# Utilizamos la función map para dibujar gráficos de dispersión en la cuadrícula (PairGrid).
g = g.map(plt.scatter)

# Ajustamos los límites del eje x, invirtiendo la dirección del eje para mostrar de 60 a 0.
g = g.set(xlim=(60, 0))

# Agregamos una leyenda para diferenciar las distintas unidades por color.
g = g.add_legend()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fd_002 =pd.read_csv("/content/drive/MyDrive/Cmapss/CMAPSS/CMaps/train_FD002.txt",sep=" ",header=None)

# %%
fd_002
# Out:
#         0    1        2       3      4       5       6        7        8   \
# 0        1    1  34.9983  0.8400  100.0  449.44  555.32  1358.61  1137.23
# 1        1    2  41.9982  0.8408  100.0  445.00  549.90  1353.22  1125.78
# 2        1    3  24.9988  0.6218   60.0  462.54  537.31  1256.76  1047.45
# 3        1    4  42.0077  0.8416  100.0  445.00  549.51  1354.03  1126.38
# 4        1    5  25.0005  0.6203   60.0  462.54  537.07  1257.71  1047.93
# ...    ...  ...      ...     ...    ...     ...     ...      ...      ...
# 53754  260  312  20.0037  0.7000  100.0  491.19  608.79  1495.60  1269.51
# 53755  260  313  10.0022  0.2510  100.0  489.05  605.81  1514.32  1324.12
# 53756  260  314  25.0041  0.6200   60.0  462.54  537.48  1276.24  1057.92
# 53757  260  315  25.0033  0.6220   60.0  462.54  537.84  1272.95  1066.30
# 53758  260  316  35.0036  0.8400  100.0  449.44  556.64  1374.61  1145.52
#
#           9   ...       18       19    20   21    22      23     24       25  \
# 0       5.48  ...  8048.56   9.3461  0.02  334  2223  100.00  14.73   8.8071
# 1       3.91  ...  8072.30   9.3774  0.02  330  2212  100.00  10.41   6.2665
# 2       7.05  ...  7864.87  10.8941  0.02  309  1915   84.93  14.08   8.6723
# 3       3.91  ...  8068.66   9.3528  0.02  329  2212  100.00  10.59   6.4701
# 4       7.05  ...  7861.23  10.8963  0.02  309  1915   84.93  14.13   8.5286
# ...      ...  ...      ...      ...   ...  ...   ...     ...    ...      ...
# 53754   9.35  ...  8169.64   9.3035  0.03  369  2324  100.00  24.36  14.5189
# 53755  10.52  ...  8245.36   8.7586  0.03  374  2319  100.00  28.10  16.9454
# 53756   7.05  ...  7971.25  11.0657  0.02  310  1915   84.93  14.19   8.5503
# 53757   7.05  ...  7972.47  11.0537  0.02  311  1915   84.93  14.05   8.3729
# 53758   5.48  ...  8185.35   9.3998  0.02  338  2223  100.00  14.75   8.8446
#
#        26  27
# 0     NaN NaN
# 1     NaN NaN
# 2     NaN NaN
# 3     NaN NaN
# 4     NaN NaN
# ...    ..  ..
# 53754 NaN NaN
# 53755 NaN NaN
# 53756 NaN NaN
# 53757 NaN NaN
# 53758 NaN NaN
#
# [53759 rows x 28 columns]

# %%
fd_002.drop(columns=[26,27],inplace=True)

# %%
columns = ['unit_number','time_in_cycles','setting_1','setting_2','TRA','T2','T24','T30','T50','P2','P15','P30','Nf','Nc','epr','Ps30','phi','NRf','NRc','BPR','farB','htBleed','Nf_dmd','PCNfR_dmd','W31','W32']

# %%
fd_002.columns = columns

# %%
fd_002
# Out:
#        unit_number  time_in_cycles  setting_1  setting_2    TRA      T2  \
# 0                1               1    34.9983     0.8400  100.0  449.44
# 1                1               2    41.9982     0.8408  100.0  445.00
# 2                1               3    24.9988     0.6218   60.0  462.54
# 3                1               4    42.0077     0.8416  100.0  445.00
# 4                1               5    25.0005     0.6203   60.0  462.54
# ...            ...             ...        ...        ...    ...     ...
# 53754          260             312    20.0037     0.7000  100.0  491.19
# 53755          260             313    10.0022     0.2510  100.0  489.05
# 53756          260             314    25.0041     0.6200   60.0  462.54
# 53757          260             315    25.0033     0.6220   60.0  462.54
# 53758          260             316    35.0036     0.8400  100.0  449.44
#
#           T24      T30      T50     P2  ...     phi      NRf      NRc  \
# 0      555.32  1358.61  1137.23   5.48  ...  183.06  2387.72  8048.56
# 1      549.90  1353.22  1125.78   3.91  ...  130.42  2387.66  8072.30
# 2      537.31  1256.76  1047.45   7.05  ...  164.22  2028.03  7864.87
# 3      549.51  1354.03  1126.38   3.91  ...  130.72  2387.61  8068.66
# 4      537.07  1257.71  1047.93   7.05  ...  164.31  2028.00  7861.23
# ...       ...      ...      ...    ...  ...     ...      ...      ...
# 53754  608.79  1495.60  1269.51   9.35  ...  314.05  2389.02  8169.64
# 53755  605.81  1514.32  1324.12  10.52  ...  371.22  2388.42  8245.36
# 53756  537.48  1276.24  1057.92   7.05  ...  163.74  2030.33  7971.25
# 53757  537.84  1272.95  1066.30   7.05  ...  164.37  2030.35  7972.47
# 53758  556.64  1374.61  1145.52   5.48  ...  183.09  2390.38  8185.35
#
#            BPR  farB  htBleed  Nf_dmd  PCNfR_dmd    W31      W32
# 0       9.3461  0.02      334    2223     100.00  14.73   8.8071
# 1       9.3774  0.02      330    2212     100.00  10.41   6.2665
# 2      10.8941  0.02      309    1915      84.93  14.08   8.6723
# 3       9.3528  0.02      329    2212     100.00  10.59   6.4701
# 4      10.8963  0.02      309    1915      84.93  14.13   8.5286
# ...        ...   ...      ...     ...        ...    ...      ...
# 53754   9.3035  0.03      369    2324     100.00  24.36  14.5189
# 53755   8.7586  0.03      374    2319     100.00  28.10  16.9454
# 53756  11.0657  0.02      310    1915      84.93  14.19   8.5503
# 53757  11.0537  0.02      311    1915      84.93  14.05   8.3729
# 53758   9.3998  0.02      338    2223     100.00  14.75   8.8446
#
# [53759 rows x 26 columns]

# %%
def prepare_train_data(data, factor = 0):
 # Hacer una copia del DataFrame original para evitar cambios en el DataFrame original
 df = data.copy()

 # Agrupar por 'unit_number' y encontrar el máximo 'time_in_cycles' para cada grupo
 # reset_index() se usa para convertir 'unit_number' de un índice a una columna
 fd_RUL = df.groupby('unit_number')['time_in_cycles'].max().reset_index()

 # Cambiar el nombre de la columna 'time_in_cycles' a 'max'
 fd_RUL.rename(columns = {'time_in_cycles':'max'}, inplace = True)

 # Combinar el DataFrame original con fd_RUL basado en 'unit_number'
 # Esto agrega la columna 'max' al DataFrame original
 df = df.merge(fd_RUL, on=['unit_number'], how='left')

 # Calcular la columna 'RUL' como la diferencia entre 'max' y 'time_in_cycles'
 df['RUL'] = df['max'] - df['time_in_cycles']

 # Eliminar la columna 'max' ya que ya no es necesaria
 df.drop(columns=['max'],inplace = True)

 # Devolver solo las filas donde 'time_in_cycles' es mayor que el factor dado
 return df[df['time_in_cycles'] > factor]

# %%
df = prepare_train_data (fd_002)

# %%
df
# Out:
#        unit_number  time_in_cycles  setting_1  setting_2    TRA      T2  \
# 0                1               1    34.9983     0.8400  100.0  449.44
# 1                1               2    41.9982     0.8408  100.0  445.00
# 2                1               3    24.9988     0.6218   60.0  462.54
# 3                1               4    42.0077     0.8416  100.0  445.00
# 4                1               5    25.0005     0.6203   60.0  462.54
# ...            ...             ...        ...        ...    ...     ...
# 53754          260             312    20.0037     0.7000  100.0  491.19
# 53755          260             313    10.0022     0.2510  100.0  489.05
# 53756          260             314    25.0041     0.6200   60.0  462.54
# 53757          260             315    25.0033     0.6220   60.0  462.54
# 53758          260             316    35.0036     0.8400  100.0  449.44
#
#           T24      T30      T50     P2  ...      NRf      NRc      BPR  farB  \
# 0      555.32  1358.61  1137.23   5.48  ...  2387.72  8048.56   9.3461  0.02
# 1      549.90  1353.22  1125.78   3.91  ...  2387.66  8072.30   9.3774  0.02
# 2      537.31  1256.76  1047.45   7.05  ...  2028.03  7864.87  10.8941  0.02
# 3      549.51  1354.03  1126.38   3.91  ...  2387.61  8068.66   9.3528  0.02
# 4      537.07  1257.71  1047.93   7.05  ...  2028.00  7861.23  10.8963  0.02
# ...       ...      ...      ...    ...  ...      ...      ...      ...   ...
# 53754  608.79  1495.60  1269.51   9.35  ...  2389.02  8169.64   9.3035  0.03
# 53755  605.81  1514.32  1324.12  10.52  ...  2388.42  8245.36   8.7586  0.03
# 53756  537.48  1276.24  1057.92   7.05  ...  2030.33  7971.25  11.0657  0.02
# 53757  537.84  1272.95  1066.30   7.05  ...  2030.35  7972.47  11.0537  0.02
# 53758  556.64  1374.61  1145.52   5.48  ...  2390.38  8185.35   9.3998  0.02
#
#        htBleed  Nf_dmd  PCNfR_dmd    W31      W32  RUL
# 0          334    2223     100.00  14.73   8.8071  148
# 1          330    2212     100.00  10.41   6.2665  147
# 2          309    1915      84.93  14.08   8.6723  146
# 3          329    2212     100.00  10.59   6.4701  145
# 4          309    1915      84.93  14.13   8.5286  144
# ...        ...     ...        ...    ...      ...  ...
# 53754      369    2324     100.00  24.36  14.5189    4
# 53755      374    2319     100.00  28.10  16.9454    3
# 53756      310    1915      84.93  14.19   8.5503    2
# 53757      311    1915      84.93  14.05   8.3729    1
# 53758      338    2223     100.00  14.75   8.8446    0
#
# [53759 rows x 27 columns]

# %% [markdown]
# FD002
# Explicacion del experimento: En esta experiencia, la evaluacion busca analizar parametros adicionales para evaluar distintas condiciones de vuelo, el objetivo fue para incluir mas variables que afectan el rendimiento de los motores. En este caso, condiciones ambientales y operativas. Lo que busca este experimento es buscar en base a el modelo de Arrhenius y el modelo de Coffin-Manson para el crecimiento de grietas mecánicas.
#
# Analisis de Resultados
# Segun grafico adjunto en Codigo, se evidencia que de las turbinas sometidas a pruebas de trabajo segun variables medidas CMAPSS(Modelado de propagacion de daño), da como resultado, que la turbina N°118 fue la que genero mayor cantidad de ciclos de trabajao hasta la aparicicion de grietas.

# %%
#Veamos cada campaña
plt.figure(figsize=(22,7))
df.unit_number.value_counts().plot.bar()
plt.xlabel('Id Simulado')
plt.ylabel('Cantidad de puntos')
# Out:
# Text(0, 0.5, 'Cantidad de puntos')

# %%
fd_003 =pd.read_csv("/content/drive/MyDrive/Cmapss/CMAPSS/CMaps/train_FD003.txt",sep=" ",header=None)

# %%
fd_003
# Out:
#         0    1       2       3      4       5       6        7        8   \
# 0        1    1 -0.0005  0.0004  100.0  518.67  642.36  1583.23  1396.84
# 1        1    2  0.0008 -0.0003  100.0  518.67  642.50  1584.69  1396.89
# 2        1    3 -0.0014 -0.0002  100.0  518.67  642.18  1582.35  1405.61
# 3        1    4 -0.0020  0.0001  100.0  518.67  642.92  1585.61  1392.27
# 4        1    5  0.0016  0.0000  100.0  518.67  641.68  1588.63  1397.65
# ...    ...  ...     ...     ...    ...     ...     ...      ...      ...
# 24715  100  148 -0.0016 -0.0003  100.0  518.67  643.78  1596.01  1424.11
# 24716  100  149  0.0034 -0.0003  100.0  518.67  643.29  1596.38  1429.14
# 24717  100  150 -0.0016  0.0004  100.0  518.67  643.84  1604.53  1431.41
# 24718  100  151 -0.0023  0.0004  100.0  518.67  643.94  1597.56  1426.57
# 24719  100  152  0.0000  0.0003  100.0  518.67  643.64  1599.04  1436.06
#
#           9   ...       18      19    20   21    22     23     24       25  \
# 0      14.62  ...  8145.32  8.4246  0.03  391  2388  100.0  39.11  23.3537
# 1      14.62  ...  8152.85  8.4403  0.03  392  2388  100.0  38.99  23.4491
# 2      14.62  ...  8150.17  8.3901  0.03  391  2388  100.0  38.85  23.3669
# 3      14.62  ...  8146.56  8.3878  0.03  392  2388  100.0  38.96  23.2951
# 4      14.62  ...  8147.80  8.3869  0.03  392  2388  100.0  39.14  23.4583
# ...      ...  ...      ...     ...   ...  ...   ...    ...    ...      ...
# 24715  14.62  ...  8138.08  8.5036  0.03  394  2388  100.0  38.44  22.9631
# 24716  14.62  ...  8144.36  8.5174  0.03  395  2388  100.0  38.50  22.9746
# 24717  14.62  ...  8135.95  8.5223  0.03  396  2388  100.0  38.39  23.0682
# 24718  14.62  ...  8141.24  8.5148  0.03  395  2388  100.0  38.31  23.0753
# 24719  14.62  ...  8136.98  8.5150  0.03  396  2388  100.0  38.56  23.0847
#
#        26  27
# 0     NaN NaN
# 1     NaN NaN
# 2     NaN NaN
# 3     NaN NaN
# 4     NaN NaN
# ...    ..  ..
# 24715 NaN NaN
# 24716 NaN NaN
# 24717 NaN NaN
# 24718 NaN NaN
# 24719 NaN NaN
#
# [24720 rows x 28 columns]

# %%
fd_003.drop(columns=[26,27],inplace=True)

# %%
columns = ['unit_number','time_in_cycles','setting_1','setting_2','TRA','T2','T24','T30','T50','P2','P15','P30','Nf','Nc','epr','Ps30','phi','NRf','NRc','BPR','farB','htBleed','Nf_dmd','PCNfR_dmd','W31','W32']

# %%
fd_003.columns = columns

# %%
fd_003
# Out:
#        unit_number  time_in_cycles  setting_1  setting_2    TRA      T2  \
# 0                1               1    -0.0005     0.0004  100.0  518.67
# 1                1               2     0.0008    -0.0003  100.0  518.67
# 2                1               3    -0.0014    -0.0002  100.0  518.67
# 3                1               4    -0.0020     0.0001  100.0  518.67
# 4                1               5     0.0016     0.0000  100.0  518.67
# ...            ...             ...        ...        ...    ...     ...
# 24715          100             148    -0.0016    -0.0003  100.0  518.67
# 24716          100             149     0.0034    -0.0003  100.0  518.67
# 24717          100             150    -0.0016     0.0004  100.0  518.67
# 24718          100             151    -0.0023     0.0004  100.0  518.67
# 24719          100             152     0.0000     0.0003  100.0  518.67
#
#           T24      T30      T50     P2  ...     phi      NRf      NRc     BPR  \
# 0      642.36  1583.23  1396.84  14.62  ...  522.31  2388.01  8145.32  8.4246
# 1      642.50  1584.69  1396.89  14.62  ...  522.42  2388.03  8152.85  8.4403
# 2      642.18  1582.35  1405.61  14.62  ...  522.03  2388.00  8150.17  8.3901
# 3      642.92  1585.61  1392.27  14.62  ...  522.49  2388.08  8146.56  8.3878
# 4      641.68  1588.63  1397.65  14.62  ...  522.58  2388.03  8147.80  8.3869
# ...       ...      ...      ...    ...  ...     ...      ...      ...     ...
# 24715  643.78  1596.01  1424.11  14.62  ...  519.66  2388.30  8138.08  8.5036
# 24716  643.29  1596.38  1429.14  14.62  ...  519.91  2388.28  8144.36  8.5174
# 24717  643.84  1604.53  1431.41  14.62  ...  519.44  2388.24  8135.95  8.5223
# 24718  643.94  1597.56  1426.57  14.62  ...  520.01  2388.26  8141.24  8.5148
# 24719  643.64  1599.04  1436.06  14.62  ...  519.48  2388.24  8136.98  8.5150
#
#        farB  htBleed  Nf_dmd  PCNfR_dmd    W31      W32
# 0      0.03      391    2388      100.0  39.11  23.3537
# 1      0.03      392    2388      100.0  38.99  23.4491
# 2      0.03      391    2388      100.0  38.85  23.3669
# 3      0.03      392    2388      100.0  38.96  23.2951
# 4      0.03      392    2388      100.0  39.14  23.4583
# ...     ...      ...     ...        ...    ...      ...
# 24715  0.03      394    2388      100.0  38.44  22.9631
# 24716  0.03      395    2388      100.0  38.50  22.9746
# 24717  0.03      396    2388      100.0  38.39  23.0682
# 24718  0.03      395    2388      100.0  38.31  23.0753
# 24719  0.03      396    2388      100.0  38.56  23.0847
#
# [24720 rows x 26 columns]

# %%
def prepare_train_data(data, factor = 0):
 # Hacer una copia del DataFrame original para evitar cambios en el DataFrame original
 df = data.copy()

 # Agrupar por 'unit_number' y encontrar el máximo 'time_in_cycles' para cada grupo
 # reset_index() se usa para convertir 'unit_number' de un índice a una columna
 fd_RUL = df.groupby('unit_number')['time_in_cycles'].max().reset_index()

 # Cambiar el nombre de la columna 'time_in_cycles' a 'max'
 fd_RUL.rename(columns = {'time_in_cycles':'max'}, inplace = True)

 # Combinar el DataFrame original con fd_RUL basado en 'unit_number'
 # Esto agrega la columna 'max' al DataFrame original
 df = df.merge(fd_RUL, on=['unit_number'], how='left')

 # Calcular la columna 'RUL' como la diferencia entre 'max' y 'time_in_cycles'
 df['RUL'] = df['max'] - df['time_in_cycles']

 # Eliminar la columna 'max' ya que ya no es necesaria
 df.drop(columns=['max'],inplace = True)

 # Devolver solo las filas donde 'time_in_cycles' es mayor que el factor dado
 return df[df['time_in_cycles'] > factor]

# %%
df = prepare_train_data (fd_003)

# %%
df
# Out:
#        unit_number  time_in_cycles  setting_1  setting_2    TRA      T2  \
# 0                1               1    -0.0005     0.0004  100.0  518.67
# 1                1               2     0.0008    -0.0003  100.0  518.67
# 2                1               3    -0.0014    -0.0002  100.0  518.67
# 3                1               4    -0.0020     0.0001  100.0  518.67
# 4                1               5     0.0016     0.0000  100.0  518.67
# ...            ...             ...        ...        ...    ...     ...
# 24715          100             148    -0.0016    -0.0003  100.0  518.67
# 24716          100             149     0.0034    -0.0003  100.0  518.67
# 24717          100             150    -0.0016     0.0004  100.0  518.67
# 24718          100             151    -0.0023     0.0004  100.0  518.67
# 24719          100             152     0.0000     0.0003  100.0  518.67
#
#           T24      T30      T50     P2  ...      NRf      NRc     BPR  farB  \
# 0      642.36  1583.23  1396.84  14.62  ...  2388.01  8145.32  8.4246  0.03
# 1      642.50  1584.69  1396.89  14.62  ...  2388.03  8152.85  8.4403  0.03
# 2      642.18  1582.35  1405.61  14.62  ...  2388.00  8150.17  8.3901  0.03
# 3      642.92  1585.61  1392.27  14.62  ...  2388.08  8146.56  8.3878  0.03
# 4      641.68  1588.63  1397.65  14.62  ...  2388.03  8147.80  8.3869  0.03
# ...       ...      ...      ...    ...  ...      ...      ...     ...   ...
# 24715  643.78  1596.01  1424.11  14.62  ...  2388.30  8138.08  8.5036  0.03
# 24716  643.29  1596.38  1429.14  14.62  ...  2388.28  8144.36  8.5174  0.03
# 24717  643.84  1604.53  1431.41  14.62  ...  2388.24  8135.95  8.5223  0.03
# 24718  643.94  1597.56  1426.57  14.62  ...  2388.26  8141.24  8.5148  0.03
# 24719  643.64  1599.04  1436.06  14.62  ...  2388.24  8136.98  8.5150  0.03
#
#        htBleed  Nf_dmd  PCNfR_dmd    W31      W32  RUL
# 0          391    2388      100.0  39.11  23.3537  258
# 1          392    2388      100.0  38.99  23.4491  257
# 2          391    2388      100.0  38.85  23.3669  256
# 3          392    2388      100.0  38.96  23.2951  255
# 4          392    2388      100.0  39.14  23.4583  254
# ...        ...     ...        ...    ...      ...  ...
# 24715      394    2388      100.0  38.44  22.9631    4
# 24716      395    2388      100.0  38.50  22.9746    3
# 24717      396    2388      100.0  38.39  23.0682    2
# 24718      395    2388      100.0  38.31  23.0753    1
# 24719      396    2388      100.0  38.56  23.0847    0
#
# [24720 rows x 27 columns]

# %% [markdown]
# FD003
# Explicacion del experimento: En esta experiencia, la evaluacion busca analizar parámetros de Salud del flujo y la eficiencia de un motor real mediante el emparejamiento óptimo de las lecturas de los sensores con los valores simulados. Esto implica utilizar un modelo adecuado que permita la variación de parámetros relacionados con la salud y grabar las mediciones resultantes de los sensores. mecánicas.
#
# Analisis de Resultados
# Segun grafico adjunto en Codigo, de 100 Turbinas somitas a pruebas de trabajo con ambiente controlado, se evidencia que la N°99 fue la menos ciclos de trabajo cumplio hasta manifestar desviaciones criticas con respecto a valores de reduccion de flujo de aire y temperatura.

# %%
#Veamos cada campaña
plt.figure(figsize=(20,6))
df.unit_number.value_counts().plot.bar()
plt.xlabel('Id Simulado')
plt.ylabel('Cantidad de puntos')
# Out:
# Text(0, 0.5, 'Cantidad de puntos')

# %%
fd_004 =pd.read_csv("/content/drive/MyDrive/Cmapss/CMAPSS/CMaps/train_FD004.txt",sep=" ",header=None)

# %%
fd_004
# Out:
#         0    1        2       3      4       5       6        7        8   \
# 0        1    1  42.0049  0.8400  100.0  445.00  549.68  1343.43  1112.93
# 1        1    2  20.0020  0.7002  100.0  491.19  606.07  1477.61  1237.50
# 2        1    3  42.0038  0.8409  100.0  445.00  548.95  1343.12  1117.05
# 3        1    4  42.0000  0.8400  100.0  445.00  548.70  1341.24  1118.03
# 4        1    5  25.0063  0.6207   60.0  462.54  536.10  1255.23  1033.59
# ...    ...  ...      ...     ...    ...     ...     ...      ...      ...
# 61244  249  251   9.9998  0.2500  100.0  489.05  605.33  1516.36  1315.28
# 61245  249  252   0.0028  0.0015  100.0  518.67  643.42  1598.92  1426.77
# 61246  249  253   0.0029  0.0000  100.0  518.67  643.68  1607.72  1430.56
# 61247  249  254  35.0046  0.8400  100.0  449.44  555.77  1381.29  1148.18
# 61248  249  255  42.0030  0.8400  100.0  445.00  549.85  1369.75  1147.45
#
#           9   ...       18       19    20   21    22      23     24       25  \
# 0       3.91  ...  8074.83   9.3335  0.02  330  2212  100.00  10.62   6.3670
# 1       9.35  ...  8046.13   9.1913  0.02  361  2324  100.00  24.37  14.6552
# 2       3.91  ...  8066.62   9.4007  0.02  329  2212  100.00  10.48   6.4213
# 3       3.91  ...  8076.05   9.3369  0.02  328  2212  100.00  10.54   6.4176
# 4       7.05  ...  7865.80  10.8366  0.02  305  1915   84.93  14.03   8.6754
# ...      ...  ...      ...      ...   ...  ...   ...     ...    ...      ...
# 61244  10.52  ...  8185.69   8.4541  0.03  372  2319  100.00  29.11  17.5234
# 61245  14.62  ...  8185.47   8.2221  0.03  396  2388  100.00  39.38  23.7151
# 61246  14.62  ...  8193.94   8.2525  0.03  395  2388  100.00  39.78  23.8270
# 61247   5.48  ...  8125.64   9.0515  0.02  337  2223  100.00  15.26   9.0774
# 61248   3.91  ...  8144.33   9.1207  0.02  333  2212  100.00  10.66   6.4341
#
#        26  27
# 0     NaN NaN
# 1     NaN NaN
# 2     NaN NaN
# 3     NaN NaN
# 4     NaN NaN
# ...    ..  ..
# 61244 NaN NaN
# 61245 NaN NaN
# 61246 NaN NaN
# 61247 NaN NaN
# 61248 NaN NaN
#
# [61249 rows x 28 columns]

# %%
fd_004.drop(columns=[26,27],inplace=True)

# %%
columns = ['unit_number','time_in_cycles','setting_1','setting_2','TRA','T2','T24','T30','T50','P2','P15','P30','Nf','Nc','epr','Ps30','phi','NRf','NRc','BPR','farB','htBleed','Nf_dmd','PCNfR_dmd','W31','W32']

# %%
fd_004.columns = columns

# %%
fd_004
# Out:
#        unit_number  time_in_cycles  setting_1  setting_2    TRA      T2  \
# 0                1               1    42.0049     0.8400  100.0  445.00
# 1                1               2    20.0020     0.7002  100.0  491.19
# 2                1               3    42.0038     0.8409  100.0  445.00
# 3                1               4    42.0000     0.8400  100.0  445.00
# 4                1               5    25.0063     0.6207   60.0  462.54
# ...            ...             ...        ...        ...    ...     ...
# 61244          249             251     9.9998     0.2500  100.0  489.05
# 61245          249             252     0.0028     0.0015  100.0  518.67
# 61246          249             253     0.0029     0.0000  100.0  518.67
# 61247          249             254    35.0046     0.8400  100.0  449.44
# 61248          249             255    42.0030     0.8400  100.0  445.00
#
#           T24      T30      T50     P2  ...     phi      NRf      NRc  \
# 0      549.68  1343.43  1112.93   3.91  ...  129.78  2387.99  8074.83
# 1      606.07  1477.61  1237.50   9.35  ...  312.59  2387.73  8046.13
# 2      548.95  1343.12  1117.05   3.91  ...  129.62  2387.97  8066.62
# 3      548.70  1341.24  1118.03   3.91  ...  129.80  2388.02  8076.05
# 4      536.10  1255.23  1033.59   7.05  ...  164.11  2028.08  7865.80
# ...       ...      ...      ...    ...  ...     ...      ...      ...
# 61244  605.33  1516.36  1315.28  10.52  ...  380.16  2388.73  8185.69
# 61245  643.42  1598.92  1426.77  14.62  ...  535.02  2388.46  8185.47
# 61246  643.68  1607.72  1430.56  14.62  ...  535.41  2388.48  8193.94
# 61247  555.77  1381.29  1148.18   5.48  ...  187.92  2388.83  8125.64
# 61248  549.85  1369.75  1147.45   3.91  ...  134.32  2388.66  8144.33
#
#            BPR  farB  htBleed  Nf_dmd  PCNfR_dmd    W31      W32
# 0       9.3335  0.02      330    2212     100.00  10.62   6.3670
# 1       9.1913  0.02      361    2324     100.00  24.37  14.6552
# 2       9.4007  0.02      329    2212     100.00  10.48   6.4213
# 3       9.3369  0.02      328    2212     100.00  10.54   6.4176
# 4      10.8366  0.02      305    1915      84.93  14.03   8.6754
# ...        ...   ...      ...     ...        ...    ...      ...
# 61244   8.4541  0.03      372    2319     100.00  29.11  17.5234
# 61245   8.2221  0.03      396    2388     100.00  39.38  23.7151
# 61246   8.2525  0.03      395    2388     100.00  39.78  23.8270
# 61247   9.0515  0.02      337    2223     100.00  15.26   9.0774
# 61248   9.1207  0.02      333    2212     100.00  10.66   6.4341
#
# [61249 rows x 26 columns]

# %%
def prepare_train_data(data, factor = 0):
 # Hacer una copia del DataFrame original para evitar cambios en el DataFrame original
 df = data.copy()

 # Agrupar por 'unit_number' y encontrar el máximo 'time_in_cycles' para cada grupo
 # reset_index() se usa para convertir 'unit_number' de un índice a una columna
 fd_RUL = df.groupby('unit_number')['time_in_cycles'].max().reset_index()

 # Cambiar el nombre de la columna 'time_in_cycles' a 'max'
 fd_RUL.rename(columns = {'time_in_cycles':'max'}, inplace = True)

 # Combinar el DataFrame original con fd_RUL basado en 'unit_number'
 # Esto agrega la columna 'max' al DataFrame original
 df = df.merge(fd_RUL, on=['unit_number'], how='left')

 # Calcular la columna 'RUL' como la diferencia entre 'max' y 'time_in_cycles'
 df['RUL'] = df['max'] - df['time_in_cycles']

 # Eliminar la columna 'max' ya que ya no es necesaria
 df.drop(columns=['max'],inplace = True)

 # Devolver solo las filas donde 'time_in_cycles' es mayor que el factor dado
 return df[df['time_in_cycles'] > factor]

# %%
df = prepare_train_data (fd_004)

# %%
df
# Out:
#        unit_number  time_in_cycles  setting_1  setting_2    TRA      T2  \
# 0                1               1    42.0049     0.8400  100.0  445.00
# 1                1               2    20.0020     0.7002  100.0  491.19
# 2                1               3    42.0038     0.8409  100.0  445.00
# 3                1               4    42.0000     0.8400  100.0  445.00
# 4                1               5    25.0063     0.6207   60.0  462.54
# ...            ...             ...        ...        ...    ...     ...
# 61244          249             251     9.9998     0.2500  100.0  489.05
# 61245          249             252     0.0028     0.0015  100.0  518.67
# 61246          249             253     0.0029     0.0000  100.0  518.67
# 61247          249             254    35.0046     0.8400  100.0  449.44
# 61248          249             255    42.0030     0.8400  100.0  445.00
#
#           T24      T30      T50     P2  ...      NRf      NRc      BPR  farB  \
# 0      549.68  1343.43  1112.93   3.91  ...  2387.99  8074.83   9.3335  0.02
# 1      606.07  1477.61  1237.50   9.35  ...  2387.73  8046.13   9.1913  0.02
# 2      548.95  1343.12  1117.05   3.91  ...  2387.97  8066.62   9.4007  0.02
# 3      548.70  1341.24  1118.03   3.91  ...  2388.02  8076.05   9.3369  0.02
# 4      536.10  1255.23  1033.59   7.05  ...  2028.08  7865.80  10.8366  0.02
# ...       ...      ...      ...    ...  ...      ...      ...      ...   ...
# 61244  605.33  1516.36  1315.28  10.52  ...  2388.73  8185.69   8.4541  0.03
# 61245  643.42  1598.92  1426.77  14.62  ...  2388.46  8185.47   8.2221  0.03
# 61246  643.68  1607.72  1430.56  14.62  ...  2388.48  8193.94   8.2525  0.03
# 61247  555.77  1381.29  1148.18   5.48  ...  2388.83  8125.64   9.0515  0.02
# 61248  549.85  1369.75  1147.45   3.91  ...  2388.66  8144.33   9.1207  0.02
#
#        htBleed  Nf_dmd  PCNfR_dmd    W31      W32  RUL
# 0          330    2212     100.00  10.62   6.3670  320
# 1          361    2324     100.00  24.37  14.6552  319
# 2          329    2212     100.00  10.48   6.4213  318
# 3          328    2212     100.00  10.54   6.4176  317
# 4          305    1915      84.93  14.03   8.6754  316
# ...        ...     ...        ...    ...      ...  ...
# 61244      372    2319     100.00  29.11  17.5234    4
# 61245      396    2388     100.00  39.38  23.7151    3
# 61246      395    2388     100.00  39.78  23.8270    2
# 61247      337    2223     100.00  15.26   9.0774    1
# 61248      333    2212     100.00  10.66   6.4341    0
#
# [61249 rows x 27 columns]

# %% [markdown]
# FD004
# Explicacion del experimento: En esta experiencia, la evaluacion busca rastrear un número de motores de aeronaves a lo largo de su historial de uso. Se asume que la cantidad de daño acumulado variará según las condiciones de vuelo y no será directamente cuantificable solo con la duración del vuelo. Se utilizan datos de sensores recogidos como Presion, temperatura de carcasa y empuje para caracterizar el estado de salud de cada turbina.
#
# Analisis de Resultados
# Segun grafico adjunto en Codigo, de las turbinas sometidas a pruebas de trabajo, la turbina N°118 realizo la mayor cantidad de vuelos hasta la primera falla, en cambio la turbina N°214 fue la que presento la primera en la menor cantidad de vuelos.

# %%
#Veamos cada campaña
plt.figure(figsize=(20,6))
df.unit_number.value_counts().plot.bar()
plt.xlabel('Id Simulado')
plt.ylabel('Cantidad de puntos')
# Out:
# Text(0, 0.5, 'Cantidad de puntos')

# %%
# Definimos la variable dependiente que queremos analizar. En este caso, 'RUL' (Remaining Useful Life).
dependent_var = ['RUL']

# Creamos un gráfico de dispersión (scatter plot) utilizando PairGrid de seaborn.
# Se filtran los datos para considerar solo las unidades con 'unit_number' menor a 100.
# Los gráficos de dispersión se crearán para cada variable (columnas) en el DataFrame 'df', utilizando 'RUL' como la variable en el eje x.
g = sns.PairGrid(data=df.query('unit_number < 100'), # Filtramos los datos para unidades menores a 100
x_vars=dependent_var, # Variable independiente 'RUL'
y_vars=df.columns, # Columnas del DataFrame a comparar contra 'RUL'
hue="unit_number", # Coloreamos los puntos según el 'unit_number'
height=2, # Altura de cada gráfico
aspect=5) # Relación de aspecto para los gráficos

# Utilizamos la función map para dibujar gráficos de dispersión en la cuadrícula (PairGrid).
g = g.map(plt.scatter)

# Ajustamos los límites del eje x, invirtiendo la dirección del eje para mostrar de 60 a 0.
g = g.set(xlim=(60, 0))

# Agregamos una leyenda para diferenciar las distintas unidades por color.
g = g.add_legend()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
