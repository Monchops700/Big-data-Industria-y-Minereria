# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
import joblib
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
file = os.path.join('C:/Users/victo/OneDrive/Escritorio/Estudios USM/Ingenieria/Computacion aplicada/Intercambiador de calor certamen/', 'Reboiler_Raw_Data_With_Timestamps.xlsx')
df1 = pd.read_excel(file, header=0)
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
# Out:
# [{'var': 'df1', 'type': 'DataFrame'}]
#                     Fecha  VAL356CI8017-Conductividad  VAL356M003-Carga Motor  \
# 0     2006-10-24 23:38:00                        12.3               68.026459
# 1     2006-10-25 01:38:00                        18.9               68.827098
# 2     2006-10-25 03:38:00                        25.9               68.871664
# 3     2006-10-25 05:38:00                        27.2               65.658285
# 4     2006-10-25 07:38:00                        22.0               64.166553
# ...                   ...                         ...                     ...
# 42201 2018-09-06 01:38:00                         7.4                     NaN
# 42202 2018-09-06 03:38:00                         7.2                     NaN
# 42203 2018-09-06 05:38:00                         6.9                     NaN
# 42204 2018-09-06 07:38:00                         6.9                     NaN
# 42205 2018-09-06 09:38:00                         7.0                     NaN
#
#        VAL356M014-Carga Motor  VAL356M015-Carga Motor  \
# 0                   45.670056               30.343173
# 1                   45.924569               30.126654
# 2                   49.477196               29.701442
# 3                   51.649763               28.820497
# 4                   46.851182               27.760388
# ...                       ...                     ...
# 42201               72.696510               43.464317
# 42202               72.905098               44.058929
# 42203               72.968914               44.584087
# 42204               72.905579               44.417335
# 42205               72.956738               44.203780
#
#        VAL356PI8026-Ind.Presión  VAL356PIC8025-Ind.Presión  \
# 0                     21.492553                       20.9
# 1                     20.954956                       20.6
# 2                     21.193045                       20.3
# 3                     21.021897                       20.6
# 4                     20.975880                       20.4
# ...                         ...                        ...
# 42201                 19.695450                       19.5
# 42202                 19.826046                       19.5
# 42203                 19.523726                       19.5
# 42204                 19.308117                       19.5
# 42205                 19.335458                       19.5
#
#        VAL356TI8015-Ind.Temperatura  VAL356TIC8014-Ind.Temperatura  Estado
# 0                         71.883617                     103.414846       0
# 1                         72.301453                     103.487449       0
# 2                         71.775536                     103.582936       0
# 3                         70.589861                     103.697800       0
# 4                         71.762377                     103.680362       0
# ...                             ...                            ...     ...
# 42201                     81.372489                      99.598170       0
# 42202                     81.911505                      99.633708       0
# 42203                     80.810454                      99.775918       0
# 42204                     81.587220                     100.136055       0
# 42205                     81.812438                     100.482443       0
#
# [42206 rows x 10 columns]

# %%
df1 = df1.drop([
	'VAL356M003-Carga Motor',
], axis='columns')
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
# Out:
# [{'var': 'df1', 'type': 'DataFrame'}]
#                     Fecha  VAL356CI8017-Conductividad  VAL356M014-Carga Motor  \
# 0     2006-10-24 23:38:00                        12.3               45.670056
# 1     2006-10-25 01:38:00                        18.9               45.924569
# 2     2006-10-25 03:38:00                        25.9               49.477196
# 3     2006-10-25 05:38:00                        27.2               51.649763
# 4     2006-10-25 07:38:00                        22.0               46.851182
# ...                   ...                         ...                     ...
# 42201 2018-09-06 01:38:00                         7.4               72.696510
# 42202 2018-09-06 03:38:00                         7.2               72.905098
# 42203 2018-09-06 05:38:00                         6.9               72.968914
# 42204 2018-09-06 07:38:00                         6.9               72.905579
# 42205 2018-09-06 09:38:00                         7.0               72.956738
#
#        VAL356M015-Carga Motor  VAL356PI8026-Ind.Presión  \
# 0                   30.343173                 21.492553
# 1                   30.126654                 20.954956
# 2                   29.701442                 21.193045
# 3                   28.820497                 21.021897
# 4                   27.760388                 20.975880
# ...                       ...                       ...
# 42201               43.464317                 19.695450
# 42202               44.058929                 19.826046
# 42203               44.584087                 19.523726
# 42204               44.417335                 19.308117
# 42205               44.203780                 19.335458
#
#        VAL356PIC8025-Ind.Presión  VAL356TI8015-Ind.Temperatura  \
# 0                           20.9                     71.883617
# 1                           20.6                     72.301453
# 2                           20.3                     71.775536
# 3                           20.6                     70.589861
# 4                           20.4                     71.762377
# ...                          ...                           ...
# 42201                       19.5                     81.372489
# 42202                       19.5                     81.911505
# 42203                       19.5                     80.810454
# 42204                       19.5                     81.587220
# 42205                       19.5                     81.812438
#
#        VAL356TIC8014-Ind.Temperatura  Estado
# 0                         103.414846       0
# 1                         103.487449       0
# 2                         103.582936       0
# 3                         103.697800       0
# 4                         103.680362       0
# ...                              ...     ...
# 42201                      99.598170       0
# 42202                      99.633708       0
# 42203                      99.775918       0
# 42204                     100.136055       0
# 42205                     100.482443       0
#
# [42206 rows x 9 columns]

# %%
df1 = df1.rename(columns={
	'VAL356CI8017-Conductividad': 'Conductividad',
	'VAL356M014-Carga Motor': 'Carga de motor de la bomba M014',
	'VAL356M015-Carga Motor': 'Carga de motor de la bomba M015',
	'VAL356PI8026-Ind.Presión': 'Sensor de presion pi8026',
	'VAL356PIC8025-Ind.Presión': 'Sensor de presion pic8025',
	'VAL356TI8015-Ind.Temperatura': 'Sensor T TI8015',
	'VAL356TIC8014-Ind.Temperatura': 'Sensor de temperatura T TIC8014',
})
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
# Out:
# [{'var': 'df1', 'type': 'DataFrame'}]
#                     Fecha  Conductividad  Carga de motor de la bomba M014  \
# 0     2006-10-24 23:38:00           12.3                        45.670056
# 1     2006-10-25 01:38:00           18.9                        45.924569
# 2     2006-10-25 03:38:00           25.9                        49.477196
# 3     2006-10-25 05:38:00           27.2                        51.649763
# 4     2006-10-25 07:38:00           22.0                        46.851182
# ...                   ...            ...                              ...
# 42201 2018-09-06 01:38:00            7.4                        72.696510
# 42202 2018-09-06 03:38:00            7.2                        72.905098
# 42203 2018-09-06 05:38:00            6.9                        72.968914
# 42204 2018-09-06 07:38:00            6.9                        72.905579
# 42205 2018-09-06 09:38:00            7.0                        72.956738
#
#        Carga de motor de la bomba M015  Sensor de presion pi8026  \
# 0                            30.343173                 21.492553
# 1                            30.126654                 20.954956
# 2                            29.701442                 21.193045
# 3                            28.820497                 21.021897
# 4                            27.760388                 20.975880
# ...                                ...                       ...
# 42201                        43.464317                 19.695450
# 42202                        44.058929                 19.826046
# 42203                        44.584087                 19.523726
# 42204                        44.417335                 19.308117
# 42205                        44.203780                 19.335458
#
#        Sensor de presion pic8025  Sensor T TI8015  \
# 0                           20.9        71.883617
# 1                           20.6        72.301453
# 2                           20.3        71.775536
# 3                           20.6        70.589861
# 4                           20.4        71.762377
# ...                          ...              ...
# 42201                       19.5        81.372489
# 42202                       19.5        81.911505
# 42203                       19.5        80.810454
# 42204                       19.5        81.587220
# 42205                       19.5        81.812438
#
#        Sensor de temperatura T TIC8014  Estado
# 0                           103.414846       0
# 1                           103.487449       0
# 2                           103.582936       0
# 3                           103.697800       0
# 4                           103.680362       0
# ...                                ...     ...
# 42201                        99.598170       0
# 42202                        99.633708       0
# 42203                        99.775918       0
# 42204                       100.136055       0
# 42205                       100.482443       0
#
# [42206 rows x 9 columns]

# %%
df1 = df1
s = df1['Fecha']
df1['Fecha'] = pd.to_datetime(s, errors='coerce')

s = df1['Conductividad']
df1['Conductividad'] = pd.to_numeric(s, errors='coerce')

s = df1['Carga de motor de la bomba M014']
df1['Carga de motor de la bomba M014'] = pd.to_numeric(s, errors='coerce')

s = df1['Carga de motor de la bomba M015']
df1['Carga de motor de la bomba M015'] = pd.to_numeric(s, errors='coerce')

s = df1['Sensor de presion pi8026']
df1['Sensor de presion pi8026'] = pd.to_numeric(s, errors='coerce')

s = df1['Sensor de presion pic8025']
df1['Sensor de presion pic8025'] = pd.to_numeric(s, errors='coerce')

s = df1['Sensor T TI8015']
df1['Sensor T TI8015'] = pd.to_numeric(s, errors='coerce')

s = df1['Sensor de temperatura T TIC8014']
df1['Sensor de temperatura T TIC8014'] = pd.to_numeric(s, errors='coerce')

attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
# Out:
# [{'var': 'df1', 'type': 'DataFrame'}]
#                     Fecha  Conductividad  Carga de motor de la bomba M014  \
# 0     2006-10-24 23:38:00           12.3                        45.670056
# 1     2006-10-25 01:38:00           18.9                        45.924569
# 2     2006-10-25 03:38:00           25.9                        49.477196
# 3     2006-10-25 05:38:00           27.2                        51.649763
# 4     2006-10-25 07:38:00           22.0                        46.851182
# ...                   ...            ...                              ...
# 42201 2018-09-06 01:38:00            7.4                        72.696510
# 42202 2018-09-06 03:38:00            7.2                        72.905098
# 42203 2018-09-06 05:38:00            6.9                        72.968914
# 42204 2018-09-06 07:38:00            6.9                        72.905579
# 42205 2018-09-06 09:38:00            7.0                        72.956738
#
#        Carga de motor de la bomba M015  Sensor de presion pi8026  \
# 0                            30.343173                 21.492553
# 1                            30.126654                 20.954956
# 2                            29.701442                 21.193045
# 3                            28.820497                 21.021897
# 4                            27.760388                 20.975880
# ...                                ...                       ...
# 42201                        43.464317                 19.695450
# 42202                        44.058929                 19.826046
# 42203                        44.584087                 19.523726
# 42204                        44.417335                 19.308117
# 42205                        44.203780                 19.335458
#
#        Sensor de presion pic8025  Sensor T TI8015  \
# 0                           20.9        71.883617
# 1                           20.6        72.301453
# 2                           20.3        71.775536
# 3                           20.6        70.589861
# 4                           20.4        71.762377
# ...                          ...              ...
# 42201                       19.5        81.372489
# 42202                       19.5        81.911505
# 42203                       19.5        80.810454
# 42204                       19.5        81.587220
# 42205                       19.5        81.812438
#
#        Sensor de temperatura T TIC8014  Estado
# 0                           103.414846       0
# 1                           103.487449       0
# 2                           103.582936       0
# 3                           103.697800       0
# 4                           103.680362       0
# ...                                ...     ...
# 42201                        99.598170       0
# 42202                        99.633708       0
# 42203                        99.775918       0
# 42204                       100.136055       0
# 42205                       100.482443       0
#
# [42206 rows x 9 columns]

# %%
df1 = df1.fillna(method='ffill')

attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_22084\3703709891.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1 = df1.fillna(method='ffill')
# [{'var': 'df1', 'type': 'DataFrame'}]
#                     Fecha  Conductividad  Carga de motor de la bomba M014  \
# 0     2006-10-24 23:38:00           12.3                        45.670056
# 1     2006-10-25 01:38:00           18.9                        45.924569
# 2     2006-10-25 03:38:00           25.9                        49.477196
# 3     2006-10-25 05:38:00           27.2                        51.649763
# 4     2006-10-25 07:38:00           22.0                        46.851182
# ...                   ...            ...                              ...
# 42201 2018-09-06 01:38:00            7.4                        72.696510
# 42202 2018-09-06 03:38:00            7.2                        72.905098
# 42203 2018-09-06 05:38:00            6.9                        72.968914
# 42204 2018-09-06 07:38:00            6.9                        72.905579
# 42205 2018-09-06 09:38:00            7.0                        72.956738
#
#        Carga de motor de la bomba M015  Sensor de presion pi8026  \
# 0                            30.343173                 21.492553
# 1                            30.126654                 20.954956
# 2                            29.701442                 21.193045
# 3                            28.820497                 21.021897
# 4                            27.760388                 20.975880
# ...                                ...                       ...
# 42201                        43.464317                 19.695450
# 42202                        44.058929                 19.826046
# 42203                        44.584087                 19.523726
# 42204                        44.417335                 19.308117
# 42205                        44.203780                 19.335458
#
#        Sensor de presion pic8025  Sensor T TI8015  \
# 0                           20.9        71.883617
# 1                           20.6        72.301453
# 2                           20.3        71.775536
# 3                           20.6        70.589861
# 4                           20.4        71.762377
# ...                          ...              ...
# 42201                       19.5        81.372489
# 42202                       19.5        81.911505
# 42203                       19.5        80.810454
# 42204                       19.5        81.587220
# 42205                       19.5        81.812438
#
#        Sensor de temperatura T TIC8014  Estado
# 0                           103.414846       0
# 1                           103.487449       0
# 2                           103.582936       0
# 3                           103.697800       0
# 4                           103.680362       0
# ...                                ...     ...
# 42201                        99.598170       0
# 42202                        99.633708       0
# 42203                        99.775918       0
# 42204                       100.136055       0
# 42205                       100.482443       0
#
# [42206 rows x 9 columns]

# %%
cond = ((df1['Fecha'].ge(pd.to_datetime('2016-01-01 00:00:00', format='%Y-%m-%d %H:%M:%S', errors='coerce'))))
df1 = df1[cond]
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
# Out:
# [{'var': 'df1', 'type': 'DataFrame'}]
#                     Fecha  Conductividad  Carga de motor de la bomba M014  \
# 30676 2016-01-08 11:38:00            4.5                        69.658713
# 30677 2016-01-08 13:38:00            4.4                        67.954487
# 30678 2016-01-08 15:38:00            4.2                        69.688606
# 30679 2016-01-08 17:38:00            4.2                        69.274182
# 30680 2016-01-08 19:38:00            4.2                        69.095421
# ...                   ...            ...                              ...
# 42201 2018-09-06 01:38:00            7.4                        72.696510
# 42202 2018-09-06 03:38:00            7.2                        72.905098
# 42203 2018-09-06 05:38:00            6.9                        72.968914
# 42204 2018-09-06 07:38:00            6.9                        72.905579
# 42205 2018-09-06 09:38:00            7.0                        72.956738
#
#        Carga de motor de la bomba M015  Sensor de presion pi8026  \
# 30676                        42.280192                 18.769251
# 30677                        42.381221                 18.411020
# 30678                        41.967134                 18.601041
# 30679                        42.124866                 18.582166
# 30680                        41.588124                 18.593953
# ...                                ...                       ...
# 42201                        43.464317                 19.695450
# 42202                        44.058929                 19.826046
# 42203                        44.584087                 19.523726
# 42204                        44.417335                 19.308117
# 42205                        44.203780                 19.335458
#
#        Sensor de presion pic8025  Sensor T TI8015  \
# 30676                       19.0        79.399877
# 30677                       19.0        78.184952
# 30678                       19.0        80.599028
# 30679                       19.0        79.301819
# 30680                       19.0        80.170472
# ...                          ...              ...
# 42201                       19.5        81.372489
# 42202                       19.5        81.911505
# 42203                       19.5        80.810454
# 42204                       19.5        81.587220
# 42205                       19.5        81.812438
#
#        Sensor de temperatura T TIC8014  Estado
# 30676                        99.160674       0
# 30677                        98.775669       0
# 30678                       101.165308       0
# 30679                        99.934365       0
# 30680                       100.804536       0
# ...                                ...     ...
# 42201                        99.598170       0
# 42202                        99.633708       0
# 42203                        99.775918       0
# 42204                       100.136055       0
# 42205                       100.482443       0
#
# [11530 rows x 9 columns]

# %%
df1 = df1
df1.set_index([
	'Fecha',
], inplace=True)
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
# Out:
# [{'var': 'df1', 'type': 'DataFrame'}]
#                      Conductividad  Carga de motor de la bomba M014  \
# Fecha
# 2016-01-08 11:38:00            4.5                        69.658713
# 2016-01-08 13:38:00            4.4                        67.954487
# 2016-01-08 15:38:00            4.2                        69.688606
# 2016-01-08 17:38:00            4.2                        69.274182
# 2016-01-08 19:38:00            4.2                        69.095421
# ...                            ...                              ...
# 2018-09-06 01:38:00            7.4                        72.696510
# 2018-09-06 03:38:00            7.2                        72.905098
# 2018-09-06 05:38:00            6.9                        72.968914
# 2018-09-06 07:38:00            6.9                        72.905579
# 2018-09-06 09:38:00            7.0                        72.956738
#
#                      Carga de motor de la bomba M015  \
# Fecha
# 2016-01-08 11:38:00                        42.280192
# 2016-01-08 13:38:00                        42.381221
# 2016-01-08 15:38:00                        41.967134
# 2016-01-08 17:38:00                        42.124866
# 2016-01-08 19:38:00                        41.588124
# ...                                              ...
# 2018-09-06 01:38:00                        43.464317
# 2018-09-06 03:38:00                        44.058929
# 2018-09-06 05:38:00                        44.584087
# 2018-09-06 07:38:00                        44.417335
# 2018-09-06 09:38:00                        44.203780
#
#                      Sensor de presion pi8026  Sensor de presion pic8025  \
# Fecha
# 2016-01-08 11:38:00                 18.769251                       19.0
# 2016-01-08 13:38:00                 18.411020                       19.0
# 2016-01-08 15:38:00                 18.601041                       19.0
# 2016-01-08 17:38:00                 18.582166                       19.0
# 2016-01-08 19:38:00                 18.593953                       19.0
# ...                                       ...                        ...
# 2018-09-06 01:38:00                 19.695450                       19.5
# 2018-09-06 03:38:00                 19.826046                       19.5
# 2018-09-06 05:38:00                 19.523726                       19.5
# 2018-09-06 07:38:00                 19.308117                       19.5
# 2018-09-06 09:38:00                 19.335458                       19.5
#
#                      Sensor T TI8015  Sensor de temperatura T TIC8014  Estado
# Fecha
# 2016-01-08 11:38:00        79.399877                        99.160674       0
# 2016-01-08 13:38:00        78.184952                        98.775669       0
# 2016-01-08 15:38:00        80.599028                       101.165308       0
# 2016-01-08 17:38:00        79.301819                        99.934365       0
# 2016-01-08 19:38:00        80.170472                       100.804536       0
# ...                              ...                              ...     ...
# 2018-09-06 01:38:00        81.372489                        99.598170       0
# 2018-09-06 03:38:00        81.911505                        99.633708       0
# 2018-09-06 05:38:00        80.810454                        99.775918       0
# 2018-09-06 07:38:00        81.587220                       100.136055       0
# 2018-09-06 09:38:00        81.812438                       100.482443       0
#
# [11530 rows x 8 columns]

# %%
cond = ((df1['Conductividad'].le(12)))
df1 = df1[cond]
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
# Out:
# [{'var': 'df1', 'type': 'DataFrame'}]
#                      Conductividad  Carga de motor de la bomba M014  \
# Fecha
# 2016-01-08 11:38:00            4.5                        69.658713
# 2016-01-08 13:38:00            4.4                        67.954487
# 2016-01-08 15:38:00            4.2                        69.688606
# 2016-01-08 17:38:00            4.2                        69.274182
# 2016-01-08 19:38:00            4.2                        69.095421
# ...                            ...                              ...
# 2018-09-06 01:38:00            7.4                        72.696510
# 2018-09-06 03:38:00            7.2                        72.905098
# 2018-09-06 05:38:00            6.9                        72.968914
# 2018-09-06 07:38:00            6.9                        72.905579
# 2018-09-06 09:38:00            7.0                        72.956738
#
#                      Carga de motor de la bomba M015  \
# Fecha
# 2016-01-08 11:38:00                        42.280192
# 2016-01-08 13:38:00                        42.381221
# 2016-01-08 15:38:00                        41.967134
# 2016-01-08 17:38:00                        42.124866
# 2016-01-08 19:38:00                        41.588124
# ...                                              ...
# 2018-09-06 01:38:00                        43.464317
# 2018-09-06 03:38:00                        44.058929
# 2018-09-06 05:38:00                        44.584087
# 2018-09-06 07:38:00                        44.417335
# 2018-09-06 09:38:00                        44.203780
#
#                      Sensor de presion pi8026  Sensor de presion pic8025  \
# Fecha
# 2016-01-08 11:38:00                 18.769251                       19.0
# 2016-01-08 13:38:00                 18.411020                       19.0
# 2016-01-08 15:38:00                 18.601041                       19.0
# 2016-01-08 17:38:00                 18.582166                       19.0
# 2016-01-08 19:38:00                 18.593953                       19.0
# ...                                       ...                        ...
# 2018-09-06 01:38:00                 19.695450                       19.5
# 2018-09-06 03:38:00                 19.826046                       19.5
# 2018-09-06 05:38:00                 19.523726                       19.5
# 2018-09-06 07:38:00                 19.308117                       19.5
# 2018-09-06 09:38:00                 19.335458                       19.5
#
#                      Sensor T TI8015  Sensor de temperatura T TIC8014  Estado
# Fecha
# 2016-01-08 11:38:00        79.399877                        99.160674       0
# 2016-01-08 13:38:00        78.184952                        98.775669       0
# 2016-01-08 15:38:00        80.599028                       101.165308       0
# 2016-01-08 17:38:00        79.301819                        99.934365       0
# 2016-01-08 19:38:00        80.170472                       100.804536       0
# ...                              ...                              ...     ...
# 2018-09-06 01:38:00        81.372489                        99.598170       0
# 2018-09-06 03:38:00        81.911505                        99.633708       0
# 2018-09-06 05:38:00        80.810454                        99.775918       0
# 2018-09-06 07:38:00        81.587220                       100.136055       0
# 2018-09-06 09:38:00        81.812438                       100.482443       0
#
# [11166 rows x 8 columns]

# %%
df1 = df1.resample('120T')

attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
enum = enumerate(df1.groups)
nextel = next(enum)
nextel[1]
df1.get_group(nextel[1])
nextel = next(enum)
nextel[1]
df1.get_group(nextel[1])
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_22084\3342230655.py:1: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df1 = df1.resample('120T')
# [{'var': 'df1', 'type': 'DatetimeIndexResampler'}]
# Timestamp('2016-01-08 10:00:00')
#                      Conductividad  Carga de motor de la bomba M014  \
# Fecha
# 2016-01-08 11:38:00            4.5                        69.658713
#
#                      Carga de motor de la bomba M015  \
# Fecha
# 2016-01-08 11:38:00                        42.280192
#
#                      Sensor de presion pi8026  Sensor de presion pic8025  \
# Fecha
# 2016-01-08 11:38:00                 18.769251                       19.0
#
#                      Sensor T TI8015  Sensor de temperatura T TIC8014  Estado
# Fecha
# 2016-01-08 11:38:00        79.399877                        99.160674       0
# Timestamp('2016-01-08 12:00:00')
#                      Conductividad  Carga de motor de la bomba M014  \
# Fecha
# 2016-01-08 13:38:00            4.4                        67.954487
#
#                      Carga de motor de la bomba M015  \
# Fecha
# 2016-01-08 13:38:00                        42.381221
#
#                      Sensor de presion pi8026  Sensor de presion pic8025  \
# Fecha
# 2016-01-08 13:38:00                  18.41102                       19.0
#
#                      Sensor T TI8015  Sensor de temperatura T TIC8014  Estado
# Fecha
# 2016-01-08 13:38:00        78.184952                        98.775669       0

# %%
df1 = df1.aggregate('median')

attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
# Out:
# [{'var': 'df1', 'type': 'DataFrame'}]
#                      Conductividad  Carga de motor de la bomba M014  \
# Fecha
# 2016-01-08 10:00:00            4.5                        69.658713
# 2016-01-08 12:00:00            4.4                        67.954487
# 2016-01-08 14:00:00            4.2                        69.688606
# 2016-01-08 16:00:00            4.2                        69.274182
# 2016-01-08 18:00:00            4.2                        69.095421
# ...                            ...                              ...
# 2018-09-06 00:00:00            7.4                        72.696510
# 2018-09-06 02:00:00            7.2                        72.905098
# 2018-09-06 04:00:00            6.9                        72.968914
# 2018-09-06 06:00:00            6.9                        72.905579
# 2018-09-06 08:00:00            7.0                        72.956738
#
#                      Carga de motor de la bomba M015  \
# Fecha
# 2016-01-08 10:00:00                        42.280192
# 2016-01-08 12:00:00                        42.381221
# 2016-01-08 14:00:00                        41.967134
# 2016-01-08 16:00:00                        42.124866
# 2016-01-08 18:00:00                        41.588124
# ...                                              ...
# 2018-09-06 00:00:00                        43.464317
# 2018-09-06 02:00:00                        44.058929
# 2018-09-06 04:00:00                        44.584087
# 2018-09-06 06:00:00                        44.417335
# 2018-09-06 08:00:00                        44.203780
#
#                      Sensor de presion pi8026  Sensor de presion pic8025  \
# Fecha
# 2016-01-08 10:00:00                 18.769251                       19.0
# 2016-01-08 12:00:00                 18.411020                       19.0
# 2016-01-08 14:00:00                 18.601041                       19.0
# 2016-01-08 16:00:00                 18.582166                       19.0
# 2016-01-08 18:00:00                 18.593953                       19.0
# ...                                       ...                        ...
# 2018-09-06 00:00:00                 19.695450                       19.5
# 2018-09-06 02:00:00                 19.826046                       19.5
# 2018-09-06 04:00:00                 19.523726                       19.5
# 2018-09-06 06:00:00                 19.308117                       19.5
# 2018-09-06 08:00:00                 19.335458                       19.5
#
#                      Sensor T TI8015  Sensor de temperatura T TIC8014  Estado
# Fecha
# 2016-01-08 10:00:00        79.399877                        99.160674     0.0
# 2016-01-08 12:00:00        78.184952                        98.775669     0.0
# 2016-01-08 14:00:00        80.599028                       101.165308     0.0
# 2016-01-08 16:00:00        79.301819                        99.934365     0.0
# 2016-01-08 18:00:00        80.170472                       100.804536     0.0
# ...                              ...                              ...     ...
# 2018-09-06 00:00:00        81.372489                        99.598170     0.0
# 2018-09-06 02:00:00        81.911505                        99.633708     0.0
# 2018-09-06 04:00:00        80.810454                        99.775918     0.0
# 2018-09-06 06:00:00        81.587220                       100.136055     0.0
# 2018-09-06 08:00:00        81.812438                       100.482443     0.0
#
# [11664 rows x 8 columns]

# %%
file = os.path.join('C:/Users/victo/OneDrive/Escritorio/Estudios USM/Ingenieria/Computacion aplicada/Intercambiador de calor certamen', 'Reboiler_Depurado.csv')
df1.to_csv(file)
attrs = {
	'var': 'empty',
	'type': 'empty',
}
[attrs]
'csv file saved'
# Out:
# [{'var': 'empty', 'type': 'empty'}]
# 'csv file saved'

# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
import joblib
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
file = os.path.join('C:/Users/victo/OneDrive/Escritorio/Estudios USM/Ingenieria/Computacion aplicada/Intercambiador de calor certamen/', 'Reboiler_Depurado.csv')
df20 = pd.read_csv(file, header=0)
attrs = {
	'var': 'df20',
	'type': type(df20).__name__,
}
[attrs]
df20
# Out:
# [{'var': 'df20', 'type': 'DataFrame'}]
#                      Fecha  Conductividad  Carga de motor de la bomba M014  \
# 0      2016-01-08 10:00:00            4.5                        69.658713
# 1      2016-01-08 12:00:00            4.4                        67.954487
# 2      2016-01-08 14:00:00            4.2                        69.688606
# 3      2016-01-08 16:00:00            4.2                        69.274182
# 4      2016-01-08 18:00:00            4.2                        69.095421
# ...                    ...            ...                              ...
# 11659  2018-09-06 00:00:00            7.4                        72.696510
# 11660  2018-09-06 02:00:00            7.2                        72.905098
# 11661  2018-09-06 04:00:00            6.9                        72.968914
# 11662  2018-09-06 06:00:00            6.9                        72.905579
# 11663  2018-09-06 08:00:00            7.0                        72.956738
#
#        Carga de motor de la bomba M015  Sensor de presion pi8026  \
# 0                            42.280192                 18.769251
# 1                            42.381221                 18.411020
# 2                            41.967134                 18.601041
# 3                            42.124866                 18.582166
# 4                            41.588124                 18.593953
# ...                                ...                       ...
# 11659                        43.464317                 19.695450
# 11660                        44.058929                 19.826046
# 11661                        44.584087                 19.523726
# 11662                        44.417335                 19.308117
# 11663                        44.203780                 19.335458
#
#        Sensor de presion pic8025  Sensor T TI8015  \
# 0                           19.0        79.399877
# 1                           19.0        78.184952
# 2                           19.0        80.599028
# 3                           19.0        79.301819
# 4                           19.0        80.170472
# ...                          ...              ...
# 11659                       19.5        81.372489
# 11660                       19.5        81.911505
# 11661                       19.5        80.810454
# 11662                       19.5        81.587220
# 11663                       19.5        81.812438
#
#        Sensor de temperatura T TIC8014  Estado
# 0                            99.160674     0.0
# 1                            98.775669     0.0
# 2                           101.165308     0.0
# 3                            99.934365     0.0
# 4                           100.804536     0.0
# ...                                ...     ...
# 11659                        99.598170     0.0
# 11660                        99.633708     0.0
# 11661                        99.775918     0.0
# 11662                       100.136055     0.0
# 11663                       100.482443     0.0
#
# [11664 rows x 9 columns]

# %%
df20 = df20
s = df20['Fecha']
df20['Fecha'] = pd.to_datetime(s, errors='coerce')

s = df20['Conductividad']
df20['Conductividad'] = pd.to_numeric(s, errors='coerce')

s = df20['Carga de motor de la bomba M014']
df20['Carga de motor de la bomba M014'] = pd.to_numeric(s, errors='coerce')

s = df20['Carga de motor de la bomba M015']
df20['Carga de motor de la bomba M015'] = pd.to_numeric(s, errors='coerce')

s = df20['Sensor de presion pi8026']
df20['Sensor de presion pi8026'] = pd.to_numeric(s, errors='coerce')

s = df20['Sensor de presion pic8025']
df20['Sensor de presion pic8025'] = pd.to_numeric(s, errors='coerce')

s = df20['Sensor T TI8015']
df20['Sensor T TI8015'] = pd.to_numeric(s, errors='coerce')

s = df20['Sensor de temperatura T TIC8014']
df20['Sensor de temperatura T TIC8014'] = pd.to_numeric(s, errors='coerce')

s = df20['Estado']
df20['Estado'] = pd.to_numeric(s, errors='coerce')

attrs = {
	'var': 'df20',
	'type': type(df20).__name__,
}
[attrs]
df20
# Out:
# [{'var': 'df20', 'type': 'DataFrame'}]
#                     Fecha  Conductividad  Carga de motor de la bomba M014  \
# 0     2016-01-08 10:00:00            4.5                        69.658713
# 1     2016-01-08 12:00:00            4.4                        67.954487
# 2     2016-01-08 14:00:00            4.2                        69.688606
# 3     2016-01-08 16:00:00            4.2                        69.274182
# 4     2016-01-08 18:00:00            4.2                        69.095421
# ...                   ...            ...                              ...
# 11659 2018-09-06 00:00:00            7.4                        72.696510
# 11660 2018-09-06 02:00:00            7.2                        72.905098
# 11661 2018-09-06 04:00:00            6.9                        72.968914
# 11662 2018-09-06 06:00:00            6.9                        72.905579
# 11663 2018-09-06 08:00:00            7.0                        72.956738
#
#        Carga de motor de la bomba M015  Sensor de presion pi8026  \
# 0                            42.280192                 18.769251
# 1                            42.381221                 18.411020
# 2                            41.967134                 18.601041
# 3                            42.124866                 18.582166
# 4                            41.588124                 18.593953
# ...                                ...                       ...
# 11659                        43.464317                 19.695450
# 11660                        44.058929                 19.826046
# 11661                        44.584087                 19.523726
# 11662                        44.417335                 19.308117
# 11663                        44.203780                 19.335458
#
#        Sensor de presion pic8025  Sensor T TI8015  \
# 0                           19.0        79.399877
# 1                           19.0        78.184952
# 2                           19.0        80.599028
# 3                           19.0        79.301819
# 4                           19.0        80.170472
# ...                          ...              ...
# 11659                       19.5        81.372489
# 11660                       19.5        81.911505
# 11661                       19.5        80.810454
# 11662                       19.5        81.587220
# 11663                       19.5        81.812438
#
#        Sensor de temperatura T TIC8014  Estado
# 0                            99.160674     0.0
# 1                            98.775669     0.0
# 2                           101.165308     0.0
# 3                            99.934365     0.0
# 4                           100.804536     0.0
# ...                                ...     ...
# 11659                        99.598170     0.0
# 11660                        99.633708     0.0
# 11661                        99.775918     0.0
# 11662                       100.136055     0.0
# 11663                       100.482443     0.0
#
# [11664 rows x 9 columns]

# %%
df20 = df20
df20.set_index([
	'Fecha',
], inplace=True)
attrs = {
	'var': 'df20',
	'type': type(df20).__name__,
}
[attrs]
df20
# Out:
# [{'var': 'df20', 'type': 'DataFrame'}]
#                      Conductividad  Carga de motor de la bomba M014  \
# Fecha
# 2016-01-08 10:00:00            4.5                        69.658713
# 2016-01-08 12:00:00            4.4                        67.954487
# 2016-01-08 14:00:00            4.2                        69.688606
# 2016-01-08 16:00:00            4.2                        69.274182
# 2016-01-08 18:00:00            4.2                        69.095421
# ...                            ...                              ...
# 2018-09-06 00:00:00            7.4                        72.696510
# 2018-09-06 02:00:00            7.2                        72.905098
# 2018-09-06 04:00:00            6.9                        72.968914
# 2018-09-06 06:00:00            6.9                        72.905579
# 2018-09-06 08:00:00            7.0                        72.956738
#
#                      Carga de motor de la bomba M015  \
# Fecha
# 2016-01-08 10:00:00                        42.280192
# 2016-01-08 12:00:00                        42.381221
# 2016-01-08 14:00:00                        41.967134
# 2016-01-08 16:00:00                        42.124866
# 2016-01-08 18:00:00                        41.588124
# ...                                              ...
# 2018-09-06 00:00:00                        43.464317
# 2018-09-06 02:00:00                        44.058929
# 2018-09-06 04:00:00                        44.584087
# 2018-09-06 06:00:00                        44.417335
# 2018-09-06 08:00:00                        44.203780
#
#                      Sensor de presion pi8026  Sensor de presion pic8025  \
# Fecha
# 2016-01-08 10:00:00                 18.769251                       19.0
# 2016-01-08 12:00:00                 18.411020                       19.0
# 2016-01-08 14:00:00                 18.601041                       19.0
# 2016-01-08 16:00:00                 18.582166                       19.0
# 2016-01-08 18:00:00                 18.593953                       19.0
# ...                                       ...                        ...
# 2018-09-06 00:00:00                 19.695450                       19.5
# 2018-09-06 02:00:00                 19.826046                       19.5
# 2018-09-06 04:00:00                 19.523726                       19.5
# 2018-09-06 06:00:00                 19.308117                       19.5
# 2018-09-06 08:00:00                 19.335458                       19.5
#
#                      Sensor T TI8015  Sensor de temperatura T TIC8014  Estado
# Fecha
# 2016-01-08 10:00:00        79.399877                        99.160674     0.0
# 2016-01-08 12:00:00        78.184952                        98.775669     0.0
# 2016-01-08 14:00:00        80.599028                       101.165308     0.0
# 2016-01-08 16:00:00        79.301819                        99.934365     0.0
# 2016-01-08 18:00:00        80.170472                       100.804536     0.0
# ...                              ...                              ...     ...
# 2018-09-06 00:00:00        81.372489                        99.598170     0.0
# 2018-09-06 02:00:00        81.911505                        99.633708     0.0
# 2018-09-06 04:00:00        80.810454                        99.775918     0.0
# 2018-09-06 06:00:00        81.587220                       100.136055     0.0
# 2018-09-06 08:00:00        81.812438                       100.482443     0.0
#
# [11664 rows x 8 columns]

# %%
df23 = df20.drop([
	'Estado',
], axis='columns')
attrs = {
	'var': 'df23',
	'type': type(df23).__name__,
}
[attrs]
df23
# Out:
# [{'var': 'df23', 'type': 'DataFrame'}]
#                      Conductividad  Carga de motor de la bomba M014  \
# Fecha
# 2016-01-08 10:00:00            4.5                        69.658713
# 2016-01-08 12:00:00            4.4                        67.954487
# 2016-01-08 14:00:00            4.2                        69.688606
# 2016-01-08 16:00:00            4.2                        69.274182
# 2016-01-08 18:00:00            4.2                        69.095421
# ...                            ...                              ...
# 2018-09-06 00:00:00            7.4                        72.696510
# 2018-09-06 02:00:00            7.2                        72.905098
# 2018-09-06 04:00:00            6.9                        72.968914
# 2018-09-06 06:00:00            6.9                        72.905579
# 2018-09-06 08:00:00            7.0                        72.956738
#
#                      Carga de motor de la bomba M015  \
# Fecha
# 2016-01-08 10:00:00                        42.280192
# 2016-01-08 12:00:00                        42.381221
# 2016-01-08 14:00:00                        41.967134
# 2016-01-08 16:00:00                        42.124866
# 2016-01-08 18:00:00                        41.588124
# ...                                              ...
# 2018-09-06 00:00:00                        43.464317
# 2018-09-06 02:00:00                        44.058929
# 2018-09-06 04:00:00                        44.584087
# 2018-09-06 06:00:00                        44.417335
# 2018-09-06 08:00:00                        44.203780
#
#                      Sensor de presion pi8026  Sensor de presion pic8025  \
# Fecha
# 2016-01-08 10:00:00                 18.769251                       19.0
# 2016-01-08 12:00:00                 18.411020                       19.0
# 2016-01-08 14:00:00                 18.601041                       19.0
# 2016-01-08 16:00:00                 18.582166                       19.0
# 2016-01-08 18:00:00                 18.593953                       19.0
# ...                                       ...                        ...
# 2018-09-06 00:00:00                 19.695450                       19.5
# 2018-09-06 02:00:00                 19.826046                       19.5
# 2018-09-06 04:00:00                 19.523726                       19.5
# 2018-09-06 06:00:00                 19.308117                       19.5
# 2018-09-06 08:00:00                 19.335458                       19.5
#
#                      Sensor T TI8015  Sensor de temperatura T TIC8014
# Fecha
# 2016-01-08 10:00:00        79.399877                        99.160674
# 2016-01-08 12:00:00        78.184952                        98.775669
# 2016-01-08 14:00:00        80.599028                       101.165308
# 2016-01-08 16:00:00        79.301819                        99.934365
# 2016-01-08 18:00:00        80.170472                       100.804536
# ...                              ...                              ...
# 2018-09-06 00:00:00        81.372489                        99.598170
# 2018-09-06 02:00:00        81.911505                        99.633708
# 2018-09-06 04:00:00        80.810454                        99.775918
# 2018-09-06 06:00:00        81.587220                       100.136055
# 2018-09-06 08:00:00        81.812438                       100.482443
#
# [11664 rows x 7 columns]

# %%
df24 = df20[[
	'Estado',
]]
attrs = {
	'var': 'df24',
	'type': type(df24).__name__,
}
[attrs]
df24
# Out:
# [{'var': 'df24', 'type': 'DataFrame'}]
#                      Estado
# Fecha
# 2016-01-08 10:00:00     0.0
# 2016-01-08 12:00:00     0.0
# 2016-01-08 14:00:00     0.0
# 2016-01-08 16:00:00     0.0
# 2016-01-08 18:00:00     0.0
# ...                     ...
# 2018-09-06 00:00:00     0.0
# 2018-09-06 02:00:00     0.0
# 2018-09-06 04:00:00     0.0
# 2018-09-06 06:00:00     0.0
# 2018-09-06 08:00:00     0.0
#
# [11664 rows x 1 columns]

# %%
def datetime_window(dfx, dfy, dfy_total, scaler, size, periods, y_choose='last', ahead=''):
    catcolsx = dfx.select_dtypes(['category']).columns
    dfx[catcolsx] = dfx[catcolsx].apply(lambda x: x.cat.codes)

    catcolsy = dfy.select_dtypes(['category']).columns
    dfy[catcolsy] = dfy[catcolsy].apply(lambda x: x.cat.codes)

    catcolsy_total = dfy_total.select_dtypes(['category']).columns
    dfy_total[catcolsy_total] = dfy_total[catcolsy_total].apply(lambda x: x.cat.codes)

    ind = []
    x = []
    y = []

    def get_windows(win):
        if (win.shape[0] != periods):
            return np.nan
        
        if (y_choose == 'ahead'):
            wy = dfy.loc[win.index, :]
            try:
                wy = dfy_total.loc[wy.index[-1] + pd.Timedelta(ahead)]
                y.append(wy)

                wx = dfx.loc[win.index, :]
                x.append(wx)

                ind.append(win.index[0])
            except:
                pass
        else:
            wx = dfx.loc[win.index, :]
            x.append(wx)

            wy = dfy.loc[win.index, :]
            if (y_choose == 'last'):
                wy = wy.iloc[-1]
            elif (y_choose == 'first'):
                wy = wy.iloc[0]
            y.append(wy)

            ind.append(win.index[0])
        
        return np.nan

    dfx.iloc[:, 0].rolling(size).apply(get_windows)
    
    return x, y, ind

# --------------------------------------------------------------------------------------
def print_list_shape(lst):
    s = ''
    if (len(lst) > 0):
        s += str(len(lst))
        s += ' x ' + str(np.array(lst[0]).shape)
    else:
        s += 'empty'
        
    return s

# --------------------------------------------------------------------------------------
def normal_anomal_split(dfx, dfy, size, periods, y_choose='last', ahead='', custom_normal_split=False, normal_test_ratio=0.1, scaler='MinMaxScaler'):
    
    if (scaler == 'MinMaxScaler'):
        myscaler = MinMaxScaler(feature_range=(0, 1))
    elif (scaler == 'StandardScaler'):
        myscaler = StandardScaler()
    elif(scaler == 'RobustScaler'):
        myscaler = RobustScaler(with_centering=True, with_scaling=True, quantile_range=(25, 75))
    
    x_windowed, y_windowed, windows_ind = datetime_window(dfx=dfx, dfy=dfy, dfy_total=dfy, scaler=myscaler, size=size, periods=periods, y_choose=y_choose, ahead=ahead)
    
    
    x_normal = []
    y_normal = []
    x_anomal = []
    y_anomal = []
    for (i, wy) in enumerate(y_windowed):
        if wy.iloc[0] == 0:
            x_normal.append(x_windowed[i])
            y_normal.append(y_windowed[i])
        else:
            x_anomal.append(x_windowed[i])
            y_anomal.append(y_windowed[i])
    
    
    normal_indices = [i for i in range(len(x_normal))]
    normal_indices_permuted = np.random.permutation(normal_indices)
    
    length = len(x_normal)
    length_test = round(length * normal_test_ratio)
    
    if custom_normal_split:
        normal_test_indices = normal_indices_permuted[:length_test]
        normal_train_indices = normal_indices_permuted[length_test:]
    else:
        normal_test_indices = normal_indices_permuted[:len(y_anomal)]
        normal_train_indices = normal_indices_permuted[len(y_anomal):]
    
    
    x_normal_train = [x_normal[i] for i in normal_train_indices]
    x_normal_test = [x_normal[i] for i in normal_test_indices]
    
    
    x_normal_train_total = pd.concat(x_normal_train)
    x_normal_train_total = x_normal_train_total[~x_normal_train_total.index.duplicated(keep='first')]
    x_normal_train_total.sort_index(inplace=True)
    
    myscaler.fit(x_normal_train_total.to_numpy())
    
    x_train = []
    for wx in x_normal_train:
        wx = wx.to_numpy()
        wx = np.squeeze(myscaler.transform(wx))
        x_train.append(wx)
    
    
    x_test = []
    y_test = []
    for wx in x_normal_test:
        wx = wx.to_numpy()
        wx = np.squeeze(myscaler.transform(wx))
        x_test.append(wx)
        y_test.append(0)
        
    for wx in x_anomal:
        wx = wx.to_numpy()
        wx = np.squeeze(myscaler.transform(wx))
        x_test.append(wx)
        y_test.append(1)
    
    x_mix = []
    for wx in x_windowed:
        wx = wx.to_numpy()
        wx = np.squeeze(myscaler.transform(wx))
        x_mix.append(wx)
    
    y_mix = []
    for wy in y_windowed:
        wy = wy.to_numpy()
        wy = wy[0]
        y_mix.append(wy)
        
    i_mix = windows_ind

    
    return x_train, x_test, y_test, x_mix, y_mix, i_mix, myscaler
x_train, x_test, y_test, x_mix, y_mix, i_mix, myscaler = normal_anomal_split(
	dfx=df23, dfy=df24
	, size='48H', periods=24, y_choose='last', ahead='2'
	, custom_normal_split=True, normal_test_ratio=0.2, scaler='MinMaxScaler')

df23 = {
	'x_train': np.array(x_train),
	'x_test': np.array(x_test),
	'y_test': np.array(y_test),
	'x_mix': np.array(x_mix),
	'y_mix': np.array(y_mix),
	'i_mix': i_mix,
	'myscaler': myscaler,
}

attrs = {
	'var': 'df23',
	'type': type(df23).__name__,
}
[attrs]

{
	'x_train': print_list_shape(x_train),
	'x_test': print_list_shape(x_test),
	'y_test': print_list_shape(y_test),
}

np.squeeze(df23['x_train'])
np.squeeze(df23['x_test'])
np.squeeze(df23['y_test'])
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_22084\3912393432.py:46: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   dfx.iloc[:, 0].rolling(size).apply(get_windows)
# [{'var': 'df23', 'type': 'dict'}]
# {'x_train': '6930 x (24, 7)',
#  'x_test': '4618 x (24, 7)',
#  'y_test': '4618 x ()'}
# array([[[0.33333333, 0.93188779, 0.83131124, ..., 0.05281286,
#          0.57011213, 0.59797969],
#         [0.34166667, 0.93045106, 0.83134429, ..., 0.05281286,
#          0.57483709, 0.5973644 ],
#         [0.34166667, 0.93300022, 0.82288041, ..., 0.05281286,
#          0.58055002, 0.59684083],
#         ...,
#         [0.38333333, 0.93318403, 0.83834814, ..., 0.05625718,
#          0.5810634 , 0.59429345],
#         [0.4       , 0.93303745, 0.84779039, ..., 0.05625718,
#          0.58386645, 0.59440194],
#         [0.41666667, 0.932295  , 0.85184068, ..., 0.05625718,
#          0.58163363, 0.59447459]],
#
#        [[0.33333333, 0.73356769, 0.82473368, ..., 0.07692308,
#          0.59193526, 0.60357432],
#         [0.34166667, 0.73290313, 0.82585467, ..., 0.07692308,
#          0.59663152, 0.60231749],
#         [0.34166667, 0.96522511, 0.83112986, ..., 0.07692308,
#          0.60774043, 0.60125396],
#         ...,
#         [0.33333333, 0.97015079, 0.83793574, ..., 0.07692308,
#          0.62589781, 0.60245601],
#         [0.325     , 0.96510705, 0.84404097, ..., 0.07692308,
#          0.6087344 , 0.59816005],
#         [0.325     , 0.96562468, 0.84434169, ..., 0.07692308,
#          0.60623445, 0.59881964]],
#
#        [[0.35      , 0.89480816, 0.75609668, ..., 0.05855339,
#          0.58335322, 0.59986707],
#         [0.36666667, 0.8977718 , 0.75509517, ..., 0.05855339,
#          0.59041371, 0.60081595],
#         [0.375     , 0.89478496, 0.7644552 , ..., 0.05855339,
#          0.59120177, 0.60098414],
#         ...,
#         [0.35      , 0.89881812, 0.71568647, ..., 0.05855339,
#          0.5892955 , 0.60395407],
#         [0.33333333, 0.90136676, 0.71560681, ..., 0.05855339,
#          0.5931208 , 0.60409643],
#         [0.34166667, 0.90029174, 0.70859613, ..., 0.05855339,
#          0.59458918, 0.60427684]],
#
#        ...,
#
#        [[0.43333333, 0.3117615 , 0.        , ..., 0.32835821,
#          0.53200223, 0.60935983],
#         [0.40833333, 0.48969637, 0.1251553 , ..., 0.14925373,
#          0.53023529, 0.60516935],
#         [0.425     , 0.38673095, 0.03659762, ..., 0.09184845,
#          0.54781807, 0.60189159],
#         ...,
#         [0.31666667, 0.94075317, 0.86873179, ..., 0.05855339,
#          0.59618451, 0.60342739],
#         [0.31666667, 0.94489281, 0.8675503 , ..., 0.05855339,
#          0.59930811, 0.60311369],
#         [0.31666667, 0.94823491, 0.88211339, ..., 0.05855339,
#          0.60176986, 0.60261902]],
#
#        [[0.15      , 0.94807056, 0.80003035, ..., 0.07003444,
#          0.61318768, 0.60210571],
#         [0.15      , 0.95012292, 0.81073739, ..., 0.07003444,
#          0.61289779, 0.6027642 ],
#         [0.15      , 0.95169847, 0.8124023 , ..., 0.07003444,
#          0.61300633, 0.60318195],
#         ...,
#         [0.16666667, 0.94510615, 0.82268824, ..., 0.07003444,
#          0.60145804, 0.60303964],
#         [0.175     , 0.94700072, 0.82447784, ..., 0.07003444,
#          0.60150159, 0.6024348 ],
#         [0.175     , 0.94586587, 0.82202997, ..., 0.07003444,
#          0.60139676, 0.60185062]],
#
#        [[0.64166667, 0.94563066, 0.89728973, ..., 0.07577497,
#          0.59699161, 0.60226874],
#         [0.63333333, 0.93547558, 0.89181925, ..., 0.07577497,
#          0.59424566, 0.60233978],
#         [0.63333333, 0.93579057, 0.88471248, ..., 0.07577497,
#          0.5914729 , 0.60254479],
#         ...,
#         [0.68333333, 0.93134851, 0.70905417, ..., 0.07577497,
#          0.57568427, 0.59948922],
#         [0.725     , 0.94022066, 0.79980378, ..., 0.07577497,
#          0.59058747, 0.59959743],
#         [0.75      , 0.9274593 , 0.79320579, ..., 0.07577497,
#          0.5883179 , 0.60026373]]])
# array([[[0.35      , 0.93486885, 0.76384985, ..., 0.05281286,
#          0.60832607, 0.6015157 ],
#         [0.35      , 0.93002214, 0.76554962, ..., 0.05281286,
#          0.60327243, 0.60141554],
#         [0.34166667, 0.93228459, 0.76670342, ..., 0.05281286,
#          0.60938024, 0.60152222],
#         ...,
#         [0.38333333, 0.93122396, 0.76939243, ..., 0.05281286,
#          0.59452007, 0.60319682],
#         [0.36666667, 0.93352962, 0.77352304, ..., 0.05281286,
#          0.60347935, 0.60402167],
#         [0.36666667, 0.93212029, 0.77441325, ..., 0.05281286,
#          0.59518444, 0.6033855 ]],
#
#        [[0.35      , 0.92933666, 0.84421178, ..., 0.05625718,
#          0.57338042, 0.59625889],
#         [0.35      , 0.92628808, 0.85846442, ..., 0.05625718,
#          0.57045251, 0.59658683],
#         [0.38333333, 0.92617575, 0.85646596, ..., 0.05625718,
#          0.57000003, 0.59680915],
#         ...,
#         [0.375     , 0.9346826 , 0.77930967, ..., 0.05625718,
#          0.57301697, 0.59538722],
#         [0.325     , 0.93573613, 0.78012906, ..., 0.05625718,
#          0.57392941, 0.59609255],
#         [0.375     , 0.93154963, 0.776512  , ..., 0.05625718,
#          0.57336637, 0.59708585]],
#
#        [[0.39166667, 0.96838696, 0.82027051, ..., 0.05855339,
#          0.72444804, 0.60655633],
#         [0.4       , 0.96706112, 0.82087991, ..., 0.05855339,
#          0.72368754, 0.60801541],
#         [0.39166667, 0.9635395 , 0.82938594, ..., 0.05855339,
#          0.72520913, 0.60994157],
#         ...,
#         [0.4       , 0.94849795, 0.82591512, ..., 0.05855339,
#          0.71200146, 0.60552381],
#         [0.40833333, 0.94653355, 0.82536038, ..., 0.05855339,
#          0.68974639, 0.60757012],
#         [0.39166667, 0.95285136, 0.8323962 , ..., 0.05855339,
#          0.68974639, 0.60757012]],
#
#        ...,
#
#        [[0.78333333, 0.92129496, 0.7056697 , ..., 0.04707233,
#          0.51986573, 0.6017715 ],
#         [0.75833333, 0.92796409, 0.70856603, ..., 0.04707233,
#          0.52928814, 0.60155323],
#         [0.73333333, 0.93226517, 0.72080339, ..., 0.04707233,
#          0.5476626 , 0.60147721],
#         ...,
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan]],
#
#        [[0.75833333, 0.92796409, 0.70856603, ..., 0.04707233,
#          0.52928814, 0.60155323],
#         [0.73333333, 0.93226517, 0.72080339, ..., 0.04707233,
#          0.5476626 , 0.60147721],
#         [0.70833333, 0.93041159, 0.73637789, ..., 0.05166475,
#          0.55136652, 0.6016435 ],
#         ...,
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan]],
#
#        [[0.73333333, 0.93226517, 0.72080339, ..., 0.04707233,
#          0.5476626 , 0.60147721],
#         [0.70833333, 0.93041159, 0.73637789, ..., 0.05166475,
#          0.55136652, 0.6016435 ],
#         [0.74166667, 0.93093917, 0.7418599 , ..., 0.05740528,
#          0.55578975, 0.60187203],
#         ...,
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan]]])
# array([0, 0, 0, ..., 1, 1, 1])

# %%
file = os.path.join('', '')
np.savez(file, x_train=df23['x_train'], x_test=df23['x_test'], y_test=df23['y_test'], x_mix=df23['x_mix'], y_mix=df23['y_mix'], i_mix=df23['i_mix'])
scaler_file = os.path.join('', 'scaler.joblib')
joblib.dump(df23['myscaler'], scaler_file)
attrs = {
	'var': 'empty',
	'type': 'empty',
}
[attrs]
'npz file saved'
